# %% [markdown]
# # Predicting the Probability of Airbnb Prices in NYC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import json
import os

import geopandas as gpd
from shapely.geometry import Point, Polygon
# %matplotlib inline

os.environ["PROJ_LIB"] = "C:\\Utilities\\Python\\Anaconda\\Library\\share";
from mpl_toolkits.basemap import Basemap
from folium.plugins import HeatMap
import plotly.graph_objs as go

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, ShuffleSplit
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression, LassoCV, RidgeClassifier, Ridge
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.compose import ColumnTransformer

from xgboost import XGBClassifier

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipe

from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, \
classification_report, accuracy_score, precision_score, plot_confusion_matrix

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('/Users/raylinsoriano/Documents/Flatiron/capstone/data/listings (1).csv')

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20210901220703   2021-09-02
# 1  3831  https://www.airbnb.com/rooms/3831  20210901220703   2021-09-02
# 2  5121  https://www.airbnb.com/rooms/5121  20210901220703   2021-09-02
# 3  5136  https://www.airbnb.com/rooms/5136  20210901220703   2021-09-02
# 4  5178  https://www.airbnb.com/rooms/5178  20210901220703   2021-09-02
#
#                                                 name  \
# 0                              Skylit Midtown Castle
# 1  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                    BlissArtsSpace!
# 3           Spacious Brooklyn Duplex, Patio + Garden
# 4                   Large Furnished Room Near B'way
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 2  <b>The space</b><br />HELLO EVERYONE AND THANK...
# 3  We welcome you to stay in our lovely 2 br dupl...
# 4  Please don’t expect the luxury here just a bas...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Just the right mix of urban center and local n...
# 2                                                NaN
# 3                                                NaN
# 4    Theater district, many restaurants around here.
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845
# 1  https://a0.muscache.com/pictures/e49999c2-9fd5...     4869
# 2  https://a0.muscache.com/pictures/2090980c-b68e...     7356
# 3  https://a0.muscache.com/pictures/miso/Hosting-...     7378
# 4  https://a0.muscache.com/pictures/12065/f070997...     8967
#
#                                  host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/2845  ...                        4.79
# 1  https://www.airbnb.com/users/show/4869  ...                        4.81
# 2  https://www.airbnb.com/users/show/7356  ...                        4.91
# 3  https://www.airbnb.com/users/show/7378  ...                        5.00
# 4  https://www.airbnb.com/users/show/8967  ...                        4.40
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.86                4.41     NaN                f
# 1                   4.72                4.65     NaN                f
# 2                   4.47                4.52     NaN                f
# 3                   4.50                5.00     NaN                f
# 4                   4.86                4.36     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              3                                           3
# 1                              1                                           1
# 2                              1                                           0
# 3                              1                                           1
# 4                              1                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.33
# 1                                           0              5.03
# 2                                           0              0.54
# 3                                           0              0.02
# 4                                           0              3.64
#
# [5 rows x 74 columns]

# %%
df.shape
# Out:
# (36923, 74)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36923 entries, 0 to 36922
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36923 non-null  int64
#  1   listing_url                                   36923 non-null  object
#  2   scrape_id                                     36923 non-null  int64
#  3   last_scraped                                  36923 non-null  object
#  4   name                                          36910 non-null  object
#  5   description                                   35710 non-null  object
#  6   neighborhood_overview                         22510 non-null  object
#  7   picture_url                                   36923 non-null  object
#  8   host_id                                       36923 non-null  int64
#  9   host_url                                      36923 non-null  object
#  10  host_name                                     36812 non-null  object
#  11  host_since                                    36812 non-null  object
#  12  host_location                                 36714 non-null  object
#  13  host_about                                    21636 non-null  object
#  14  host_response_time                            21180 non-null  object
#  15  host_response_rate                            21180 non-null  object
#  16  host_acceptance_rate                          21821 non-null  object
#  17  host_is_superhost                             36812 non-null  object
#  18  host_thumbnail_url                            36812 non-null  object
#  19  host_picture_url                              36812 non-null  object
#  20  host_neighbourhood                            29726 non-null  object
#  21  host_listings_count                           36812 non-null  float64
#  22  host_total_listings_count                     36812 non-null  float64
#  23  host_verifications                            36923 non-null  object
#  24  host_has_profile_pic                          36812 non-null  object
#  25  host_identity_verified                        36812 non-null  object
#  26  neighbourhood                                 22511 non-null  object
#  27  neighbourhood_cleansed                        36923 non-null  object
#  28  neighbourhood_group_cleansed                  36923 non-null  object
#  29  latitude                                      36923 non-null  float64
#  30  longitude                                     36923 non-null  float64
#  31  property_type                                 36923 non-null  object
#  32  room_type                                     36923 non-null  object
#  33  accommodates                                  36923 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                36818 non-null  object
#  36  bedrooms                                      32987 non-null  float64
#  37  beds                                          36312 non-null  float64
#  38  amenities                                     36923 non-null  object
#  39  price                                         36923 non-null  object
#  40  minimum_nights                                36923 non-null  int64
#  41  maximum_nights                                36923 non-null  int64
#  42  minimum_minimum_nights                        36906 non-null  float64
#  43  maximum_minimum_nights                        36906 non-null  float64
#  44  minimum_maximum_nights                        36906 non-null  float64
#  45  maximum_maximum_nights                        36906 non-null  float64
#  46  minimum_nights_avg_ntm                        36906 non-null  float64
#  47  maximum_nights_avg_ntm                        36906 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              36923 non-null  object
#  50  availability_30                               36923 non-null  int64
#  51  availability_60                               36923 non-null  int64
#  52  availability_90                               36923 non-null  int64
#  53  availability_365                              36923 non-null  int64
#  54  calendar_last_scraped                         36923 non-null  object
#  55  number_of_reviews                             36923 non-null  int64
#  56  number_of_reviews_ltm                         36923 non-null  int64
#  57  number_of_reviews_l30d                        36923 non-null  int64
#  58  first_review                                  27627 non-null  object
#  59  last_review                                   27627 non-null  object
#  60  review_scores_rating                          27627 non-null  float64
#  61  review_scores_accuracy                        26998 non-null  float64
#  62  review_scores_cleanliness                     27009 non-null  float64
#  63  review_scores_checkin                         26991 non-null  float64
#  64  review_scores_communication                   27002 non-null  float64
#  65  review_scores_location                        26987 non-null  float64
#  66  review_scores_value                           26987 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              36923 non-null  object
#  69  calculated_host_listings_count                36923 non-null  int64
#  70  calculated_host_listings_count_entire_homes   36923 non-null  int64
#  71  calculated_host_listings_count_private_rooms  36923 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   36923 non-null  int64
#  73  reviews_per_month                             27627 non-null  float64
# dtypes: float64(23), int64(17), object(34)
# memory usage: 20.8+ MB

# %%
pd.options.display.max_rows = 4000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# name                                               13
# description                                      1213
# neighborhood_overview                           14413
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                         111
# host_since                                        111
# host_location                                     209
# host_about                                      15287
# host_response_time                              15743
# host_response_rate                              15743
# host_acceptance_rate                            15102
# host_is_superhost                                 111
# host_thumbnail_url                                111
# host_picture_url                                  111
# host_neighbourhood                               7197
# host_listings_count                               111
# host_total_listings_count                         111
# host_verifications                                  0
# host_has_profile_pic                              111
# host_identity_verified                            111
# neighbourhood                                   14412
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                        0
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                       36923
# bathrooms_text                                    105
# bedrooms                                         3936
# beds                                              611
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                             17
# maximum_minimum_nights                             17
# minimum_maximum_nights                             17
# maximum_maximum_nights                             17
# minimum_nights_avg_ntm                             17
# maximum_nights_avg_ntm                             17
# calendar_updated                                36923
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                     9296
# last_review                                      9296
# review_scores_rating                             9296
# review_scores_accuracy                           9925
# review_scores_cleanliness                        9914
# review_scores_checkin                            9932
# review_scores_communication                      9921
# review_scores_location                           9936
# review_scores_value                              9936
# license                                         36923
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                9296
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %%
df['host_response_rate'].replace('[\%,]', '', regex=True).astype(float)
df['host_acceptance_rate'].replace('[\%,]', '', regex=True).astype(float)
# Out:
# 0         19.0
# 1         86.0
# 2          NaN
# 3         33.0
# 4        100.0
#          ...
# 36918     96.0
# 36919     25.0
# 36920     78.0
# 36921     25.0
# 36922    100.0
# Name: host_acceptance_rate, Length: 36923, dtype: float64

# %%
# Created a column for how many years the airbnb has been a host
df['host_since'] = pd.to_datetime(df['host_since'])
df['year'] = df['host_since'].apply(lambda date: date.year)

df['years_been_host'] = max(df['year']) - df['year']

# %%
#Created a column of how many verifications each host has
df['number_of_verifications'] = df.host_verifications.str.count(',')+1

# %%
#Created a column of how many amenities each host has
df['number_of_amenities'] = df.amenities.str.count(',')+1

# %%
df['bathrooms_text'] = df.bathrooms_text.str.extract('(\d+)').astype(float)

# %%
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
median = df.filter(['host_listings_count','beds', 'bedrooms'
                    ,'accommodates','years_been_host','bathrooms_text']).median()

# %%
cols = ['host_listings_count','beds', 'bedrooms','accommodates','years_been_host','bathrooms_text']                          
df[cols]=df[cols].fillna(median)

# %%
mean = df.filter(['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
        'review_scores_communication', 'review_scores_location', 'review_scores_value']).mean()

# %%
cols2 = ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
        'review_scores_communication', 'review_scores_location','review_scores_value']                          
df[cols2]=df[cols2].fillna(mean)

# %%
df = df.fillna(df.mode().iloc[0])

# %%
df["last_scraped"].value_counts()
# Out:
# 2021-09-02    32883
# 2021-09-03     2629
# 2021-09-01     1293
# 2021-09-06      118
# Name: last_scraped, dtype: int64

# %%
df['calendar_last_scraped'].value_counts()
# Out:
# 2021-09-02    32912
# 2021-09-03     2600
# 2021-09-01     1293
# 2021-09-06      118
# Name: calendar_last_scraped, dtype: int64

# %%
df['host_since'].min()
# Out:
# Timestamp('2008-08-22 00:00:00')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36923 entries, 0 to 36922
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36923 non-null  int64
#  1   listing_url                                   36923 non-null  object
#  2   scrape_id                                     36923 non-null  int64
#  3   last_scraped                                  36923 non-null  object
#  4   name                                          36923 non-null  object
#  5   description                                   36923 non-null  object
#  6   neighborhood_overview                         36923 non-null  object
#  7   picture_url                                   36923 non-null  object
#  8   host_id                                       36923 non-null  int64
#  9   host_url                                      36923 non-null  object
#  10  host_name                                     36923 non-null  object
#  11  host_since                                    36923 non-null  datetime64[ns]
#  12  host_location                                 36923 non-null  object
#  13  host_about                                    36923 non-null  object
#  14  host_response_time                            36923 non-null  object
#  15  host_response_rate                            36923 non-null  object
#  16  host_acceptance_rate                          36923 non-null  object
#  17  host_is_superhost                             36923 non-null  object
#  18  host_thumbnail_url                            36923 non-null  object
#  19  host_picture_url                              36923 non-null  object
#  20  host_neighbourhood                            36923 non-null  object
#  21  host_listings_count                           36923 non-null  float64
#  22  host_total_listings_count                     36923 non-null  float64
#  23  host_verifications                            36923 non-null  object
#  24  host_has_profile_pic                          36923 non-null  object
#  25  host_identity_verified                        36923 non-null  object
#  26  neighbourhood                                 36923 non-null  object
#  27  neighbourhood_cleansed                        36923 non-null  object
#  28  neighbourhood_group_cleansed                  36923 non-null  object
#  29  latitude                                      36923 non-null  float64
#  30  longitude                                     36923 non-null  float64
#  31  property_type                                 36923 non-null  object
#  32  room_type                                     36923 non-null  object
#  33  accommodates                                  36923 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                36923 non-null  float64
#  36  bedrooms                                      36923 non-null  float64
#  37  beds                                          36923 non-null  float64
#  38  amenities                                     36923 non-null  object
#  39  price                                         36923 non-null  float64
#  40  minimum_nights                                36923 non-null  int64
#  41  maximum_nights                                36923 non-null  int64
#  42  minimum_minimum_nights                        36923 non-null  float64
#  43  maximum_minimum_nights                        36923 non-null  float64
#  44  minimum_maximum_nights                        36923 non-null  float64
#  45  maximum_maximum_nights                        36923 non-null  float64
#  46  minimum_nights_avg_ntm                        36923 non-null  float64
#  47  maximum_nights_avg_ntm                        36923 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              36923 non-null  object
#  50  availability_30                               36923 non-null  int64
#  51  availability_60                               36923 non-null  int64
#  52  availability_90                               36923 non-null  int64
#  53  availability_365                              36923 non-null  int64
#  54  calendar_last_scraped                         36923 non-null  object
#  55  number_of_reviews                             36923 non-null  int64
#  56  number_of_reviews_ltm                         36923 non-null  int64
#  57  number_of_reviews_l30d                        36923 non-null  int64
#  58  first_review                                  36923 non-null  object
#  59  last_review                                   36923 non-null  object
#  60  review_scores_rating                          36923 non-null  float64
#  61  review_scores_accuracy                        36923 non-null  float64
#  62  review_scores_cleanliness                     36923 non-null  float64
#  63  review_scores_checkin                         36923 non-null  float64
#  64  review_scores_communication                   36923 non-null  float64
#  65  review_scores_location                        36923 non-null  float64
#  66  review_scores_value                           36923 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              36923 non-null  object
#  69  calculated_host_listings_count                36923 non-null  int64
#  70  calculated_host_listings_count_entire_homes   36923 non-null  int64
#  71  calculated_host_listings_count_private_rooms  36923 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   36923 non-null  int64
#  73  reviews_per_month                             36923 non-null  float64
#  74  year                                          36923 non-null  float64
#  75  years_been_host                               36923 non-null  float64
#  76  number_of_verifications                       36923 non-null  int64
#  77  number_of_amenities                           36923 non-null  int64
# dtypes: datetime64[ns](1), float64(27), int64(19), object(31)
# memory usage: 22.0+ MB

# %% [markdown]
# ### Graphs

# %%
# set the filepath and load in a shapefile
fp = '/Users/raylinsoriano/Documents/Flatiron/capstone/data/Borough Boundaries.zip'
map_df = gpd.read_file(fp)
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#    boro_code      boro_name    shape_area     shape_leng  \
# 0        2.0          Bronx  1.187194e+09  463868.937681
# 1        1.0      Manhattan  6.365759e+08  359804.890798
# 2        5.0  Staten Island  1.623636e+09  325929.794027
# 3        3.0       Brooklyn  1.934174e+09  728195.197649
# 4        4.0         Queens  3.040205e+09  900270.512975
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...
# 1  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 2  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 3  MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...
# 4  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
# Creating a dataframe of listing counts and median price by borough
borough_df = pd.DataFrame(df.groupby('neighbourhood_group_cleansed').size())
#borough_df.rename(columns={0: 'number_of_listings'}, inplace=True)
borough_df['median_price'] = df.groupby('neighbourhood_group_cleansed').price.median().values
borough_df['median_rating'] = df.groupby('neighbourhood_group_cleansed').review_scores_rating.median().values
# Joining the dataframes
borough_map_df = map_df.set_index('boro_name').join(borough_df)

borough_map_df.head()
# Out:
#                boro_code    shape_area     shape_leng  \
# boro_name
# Bronx                2.0  1.187194e+09  463868.937681
# Manhattan            1.0  6.365759e+08  359804.890798
# Staten Island        5.0  1.623636e+09  325929.794027
# Brooklyn             3.0  1.934174e+09  728195.197649
# Queens               4.0  3.040205e+09  900270.512975
#
#                                                         geometry      0  \
# boro_name
# Bronx          MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...   1026
# Manhattan      MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...  16242
# Staten Island  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...    313
# Brooklyn       MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...  14392
# Queens         MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...   4950
#
#                median_price  median_rating
# boro_name
# Bronx                  75.0           4.70
# Manhattan             146.0           4.59
# Staten Island          90.0           4.80
# Brooklyn               99.0           4.74
# Queens                 75.0           4.67

# %%
# Plotting the median price of listings in each borough
fig2, ax2 = plt.subplots(1, figsize=(15, 10))
borough_map_df.plot(column='median_price', cmap='Reds', ax=ax2)

ax2.axis('off')
ax2.set_title('Median price of Airbnb listings in each NYC borough', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=min(borough_map_df.median_price), vmax=max(borough_map_df.median_price)))
sm._A = [] # Creates an empty array for the data range
cbar = fig2.colorbar(sm)
plt.show()

# %%
plt.figure(figsize=(13,7))
plt.title("Host Repsonse time")
host_response_time_graph = sns.countplot(df.host_response_time, palette="muted")
host_response_time_graph.set_xlabel("Host Repsonse time")
fig = plt.gcf()
plt.show()
# Out:
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
attractions = pd.read_csv('/Users/raylinsoriano/Documents/Flatiron/capstone/data/cultural-institutions-by-block-and-lot.csv')

# %%
attractions.shape
# Out:
# (70, 15)

# %%
attractions = attractions.dropna()

# %%
attractions.isna().sum()
# Out:
# Organization Name                                               0
# Preferred Address Line 1                                        0
# Preferred Block-Lot Number                                      0
# Constituency Code                                               0
# Constituent Specific Attributes R-Secondary Type Description    0
# Borough                                                         0
# Postcode                                                        0
# Latitude                                                        0
# Longitude                                                       0
# Community Board                                                 0
# Council District                                                0
# Census Tract                                                    0
# BIN                                                             0
# BBL                                                             0
# NTA                                                             0
# dtype: int64

# %%
 attractions['Latitude'].iloc[0]
# Out:
# 40.715781

# %%
lng1 = attractions['Longitude'].iloc[0]

# %%
attractions
# Out:
#                                     Organization Name  \
# 3                   Action Center To End World Hunger
# 4                                Circle Line Downtown
# 5                                Circle Line Downtown
# 6                                  3 Legged Dog, Inc.
# 7                    Church of Our Lady of the Rosary
# 8                                      Trinity Church
# 10                         Museum of American Finance
# 11                              Bodies The Exhibition
# 51                   100 Old Slip                       34-1
# 52                 26 Wall Street                       43-1
# 53                20 Vesey Street                       88-5
# 54              105 Nassau Street                      90-20
# 55             120 Liberty Street                      52-21
# 56                     1 Broadway                       13-1
# 58              47 Beekman Street                      93-29
# 59              47 Beekman Street                      93-29
# 60  South Street Seaport, Pier 17                      73-10
# 61               10 River Terrace                    16-7516
# 62               10 River Terrace                    16-7516
# 63               10 River Terrace                    16-7516
# 64               12 Fulton Street                       74-1
# 65               206 Front Street                       96-5
# 66         250 Greenwich Street,                       25-10
# 67           175 North End Avenue                    16-7516
# 68  South Street Seaport, Pier 17                      73-10
# 69                         Pier A                      1-Mar
#
#             Constituency Code  \
# 3                Retail Space
# 4                Retail Space
# 5          DLMA Former Member
# 6                Retail Space
# 7                Retail Space
# 8                Retail Space
# 10               Retail Space
# 11       Cultural Institution
# 12               Retail Space
# 14               Retail Space
# 15       Cultural Institution
# 16               Retail Space
# 17  Commercial Property Owner
# 18               Retail Space
# 19               Retail Space
# 21                DLMA Member
# 22                Corporation
# 23               Retail Space
# 24               Retail Space
# 25               Retail Space
# 26               Retail Space
# 29               Retail Space
# 30               Retail Space
# 33               Retail Space
# 34               Retail Space
# 35      Religious Institution
# 36               Retail Space
# 37               Retail Space
# 39               Retail Space
# 41               Retail Space
# 42               Retail Space
# 43      Religious Institution
# 44               Retail Space
# 45  Commercial Property Owner
# 46               Retail Space
# 47  Commercial Property Owner
# 48               Retail Space
# 49               Retail Space
# 50               Retail Space
# 51               Retail Space
# 52               Retail Space
# 53               Retail Space
# 54               Retail Space
# 55               Retail Space
# 56               Retail Space
# 58               Retail Space
# 59  Commercial Property Owner
# 60               Retail Space
# 61                 Non-Profit
# 62                DLMA Member
# 63               Retail Space
# 64               Retail Space
# 65               Retail Space
# 66               Retail Space
# 67               Retail Space
# 68                Corporation
# 69               Retail Space
#
#    Constituent Specific Attributes R-Secondary Type Description    Borough  \
# 3                         A-Museums & Performing Arts            Manhattan
# 4                                       V-Sightseeing            Manhattan
# 5                                       V-Sightseeing            Manhattan
# 6                                A-Theaters & Cinemas            Manhattan
# 7                            C-Religious Institutions            Manhattan
# 8                            C-Religious Institutions            Manhattan
# 10                        A-Museums & Performing Arts            Manhattan
# 11                        A-Museums & Performing Arts            Manhattan
# 12                        A-Museums & Performing Arts            Manhattan
# 14                        A-Museums & Performing Arts            Manhattan
# 15                        A-Museums & Performing Arts            Manhattan
# 16                        A-Museums & Performing Arts            Manhattan
# 17                        A-Museums & Performing Arts            Manhattan
# 18                                      V-Sightseeing            Manhattan
# 19                           C-Religious Institutions            Manhattan
# 21                                      V-Sightseeing            Manhattan
# 22                                      V-Sightseeing            Manhattan
# 23                                      V-Sightseeing            Manhattan
# 24                          A-Attractions & Landmarks            Manhattan
# 25                          A-Attractions & Landmarks            Manhattan
# 26                        A-Museums & Performing Arts            Manhattan
# 29                                      V-Sightseeing            Manhattan
# 30                               A-Theaters & Cinemas            Manhattan
# 33                           C-Religious Institutions            Manhattan
# 34                           C-Religious Institutions            Manhattan
# 35                           C-Religious Institutions            Manhattan
# 36                                   C-Public Library            Manhattan
# 37                               A-Theaters & Cinemas            Manhattan
# 39                          A-Attractions & Landmarks            Manhattan
# 41                        A-Museums & Performing Arts            Manhattan
# 42                           C-Religious Institutions            Manhattan
# 43                           C-Religious Institutions            Manhattan
# 44                           C-Religious Institutions            Manhattan
# 45                           C-Religious Institutions            Manhattan
# 46                           C-Religious Institutions            Manhattan
# 47                           C-Religious Institutions            Manhattan
# 48                                      V-Sightseeing            Manhattan
# 49                        A-Museums & Performing Arts            Manhattan
# 50                               A-Theaters & Cinemas            Manhattan
# 51                        A-Museums & Performing Arts            Manhattan
# 52                          A-Attractions & Landmarks            Manhattan
# 53                          A-Attractions & Landmarks            Manhattan
# 54                        A-Museums & Performing Arts            Manhattan
# 55                        A-Museums & Performing Arts            Manhattan
# 56                        A-Museums & Performing Arts            Manhattan
# 58                           C-Religious Institutions            Manhattan
# 59                           C-Religious Institutions            Manhattan
# 60                                      V-Sightseeing            Manhattan
# 61                        A-Museums & Performing Arts            Manhattan
# 62                        A-Museums & Performing Arts            Manhattan
# 63                        A-Museums & Performing Arts            Manhattan
# 64                        A-Museums & Performing Arts            Manhattan
# 65                          A-Attractions & Landmarks            Manhattan
# 66                           C-Religious Institutions            Manhattan
# 67                                   C-Public Library            Manhattan
# 68                                      V-Sightseeing            Manhattan
# 69                                      V-Sightseeing            Manhattan
#
#     Postcode   Latitude  Longitude  Community Board  Council District  \
# 3    10282.0  40.715781 -74.016518              1.0               1.0
# 4    10038.0  40.705717 -74.002453              1.0               1.0
# 5    10038.0  40.705717 -74.002453              1.0               1.0
# 6    10006.0  40.707514 -74.013800              1.0               1.0
# 7    10004.0  40.702398 -74.013287              1.0               1.0
# 8    10006.0  40.708387 -74.012563              1.0               1.0
# 10   10005.0  40.706331 -74.009396              1.0               1.0
# 11   10038.0  40.706639 -74.003477              1.0               1.0
# 12   10038.0  40.706639 -74.003477              1.0               1.0
# 14   10280.0  40.705869 -74.017994              1.0               1.0
# 15   10280.0  40.705869 -74.017994              1.0               1.0
# 16   10280.0  40.705806 -74.018019              1.0               1.0
# 17   10280.0  40.705806 -74.018019              1.0               1.0
# 18   10038.0  40.705717 -74.002453              1.0               1.0
# 19   10282.0  40.716668 -74.013542              1.0               1.0
# 21   10005.0  40.707399 -74.011105              1.0               1.0
# 22   10005.0  40.707399 -74.011105              1.0               1.0
# 23   10005.0  40.707399 -74.011105              1.0               1.0
# 24   10038.0  40.706916 -74.003697              1.0               1.0
# 25   10007.0  40.710967 -74.009000              1.0               1.0
# 26   10281.0  40.714120 -74.014750              1.0               1.0
# 29   10036.0  40.756087 -73.981072              5.0               4.0
# 30   10038.0  40.711909 -74.005843              1.0               1.0
# 33   10038.0  40.707981 -74.002471              1.0               1.0
# 34   10280.0  40.711329 -74.015893              1.0               1.0
# 35   10280.0  40.711329 -74.015893              1.0               1.0
# 36   10007.0  40.713314 -74.007759              1.0               1.0
# 37   10038.0  40.707712 -74.001508              1.0               1.0
# 39   10007.0  40.714807 -74.005764              1.0               1.0
SoHo-TriBeCa-Civic Center-Little Italy        ...
# 67  Battery Park City-Lower Manhattan             ...
# 68  Battery Park City-Lower Manhattan             ...
# 69  Battery Park City-Lower Manhattan             ...

# %%
lng2= df['longitude'].iloc[0]

# %%
lat2 = df['latitude'].iloc[0]

# %%
def haversine_array(lat1, lng1, lat2, lng2):
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    AVG_EARTH_RADIUS = 6371  # in km
    lat = lat2 - lat1
    lng = lng2 - lng1
    d = np.sin(lat * 0.5) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(lng * 0.5) ** 2
    h = 2 * AVG_EARTH_RADIUS * np.arcsin(np.sqrt(d))
    return h

# %%
def dummy_manhattan_distance(lat1, lng1, lat2, lng2):
    a = haversine_array(lat1, lng1, lat1, lng2)
    b = haversine_array(lat1, lng1, lat2, lng1)
    return a + b

# %%
#haversine_array(lat1, lng1, lat2, lng2)

# %%
#dummy_manhattan_distance(lat1, lng1, lat2, lng2)

# %%
crs = {'init': 'epsg:4326'}
geo = [Point(xy) for xy in zip( df['longitude'], df['latitude'])]
print(geo[:3])





geo_df = gpd.GeoDataFrame(df, crs=crs,  geometry=geo )
geo_df = geo_df[geo_df['longitude'] != 0.0]
# Out:
# [<shapely.geometry.point.Point object at 0x7fa3491fdb80>, <shapely.geometry.point.Point object at 0x7fa3570118e0>, <shapely.geometry.point.Point object at 0x7fa302ae6280>]
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
# fig, ax = plt.subplots(figsize = (18,18))
# map_df.plot(ax = ax, alpha = 0.4, color = 'grey')
# geo_df[geo_df['MOST_SEVERE_INJURY'] == 'severe'].plot(ax = ax, 
#                                                         markersize = 10, 
#                                                         color = 'blue', 
#                                                         marker = 'o', 
#                                                         label = 'severe')

# %%
#Created a column for how many years the airbnb has been a host
df['host_since'] = pd.to_datetime(df['host_since'])
df['year'] = df['host_since'].apply(lambda date: date.year)

df['years_been_host'] = max(df['year']) - df['year']

# %%
#Distance from time sqaure
df['distance_ts'] = dummy_manhattan_distance(df['latitude'], df['longitude'], lat2=40.7580, lng2=73.9855)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36923 entries, 0 to 36922
# Data columns (total 80 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36923 non-null  int64
#  1   listing_url                                   36923 non-null  object
#  2   scrape_id                                     36923 non-null  int64
#  3   last_scraped                                  36923 non-null  object
#  4   name                                          36923 non-null  object
#  5   description                                   36923 non-null  object
#  6   neighborhood_overview                         36923 non-null  object
#  7   picture_url                                   36923 non-null  object
#  8   host_id                                       36923 non-null  int64
#  9   host_url                                      36923 non-null  object
#  10  host_name                                     36923 non-null  object
#  11  host_since                                    36923 non-null  datetime64[ns]
#  12  host_location                                 36923 non-null  object
#  13  host_about                                    36923 non-null  object
#  14  host_response_time                            36923 non-null  object
#  15  host_response_rate                            36923 non-null  object
#  16  host_acceptance_rate                          36923 non-null  object
#  17  host_is_superhost                             36923 non-null  object
#  18  host_thumbnail_url                            36923 non-null  object
#  19  host_picture_url                              36923 non-null  object
#  20  host_neighbourhood                            36923 non-null  object
#  21  host_listings_count                           36923 non-null  float64
#  22  host_total_listings_count                     36923 non-null  float64
#  23  host_verifications                            36923 non-null  object
#  24  host_has_profile_pic                          36923 non-null  object
#  25  host_identity_verified                        36923 non-null  object
#  26  neighbourhood                                 36923 non-null  object
#  27  neighbourhood_cleansed                        36923 non-null  object
#  28  neighbourhood_group_cleansed                  36923 non-null  object
#  29  latitude                                      36923 non-null  float64
#  30  longitude                                     36923 non-null  float64
#  31  property_type                                 36923 non-null  object
#  32  room_type                                     36923 non-null  object
#  33  accommodates                                  36923 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                36923 non-null  float64
#  36  bedrooms                                      36923 non-null  float64
#  37  beds                                          36923 non-null  float64
#  38  amenities                                     36923 non-null  object
#  39  price                                         36923 non-null  float64
#  40  minimum_nights                                36923 non-null  int64
#  41  maximum_nights                                36923 non-null  int64
#  42  minimum_minimum_nights                        36923 non-null  float64
#  43  maximum_minimum_nights                        36923 non-null  float64
#  44  minimum_maximum_nights                        36923 non-null  float64
#  45  maximum_maximum_nights                        36923 non-null  float64
#  46  minimum_nights_avg_ntm                        36923 non-null  float64
#  47  maximum_nights_avg_ntm                        36923 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              36923 non-null  object
#  50  availability_30                               36923 non-null  int64
#  51  availability_60                               36923 non-null  int64
#  52  availability_90                               36923 non-null  int64
#  53  availability_365                              36923 non-null  int64
#  54  calendar_last_scraped                         36923 non-null  object
#  55  number_of_reviews                             36923 non-null  int64
#  56  number_of_reviews_ltm                         36923 non-null  int64
#  57  number_of_reviews_l30d                        36923 non-null  int64
#  58  first_review                                  36923 non-null  object
#  59  last_review                                   36923 non-null  object
#  60  review_scores_rating                          36923 non-null  float64
#  61  review_scores_accuracy                        36923 non-null  float64
#  62  review_scores_cleanliness                     36923 non-null  float64
#  63  review_scores_checkin                         36923 non-null  float64
#  64  review_scores_communication                   36923 non-null  float64
#  65  review_scores_location                        36923 non-null  float64
#  66  review_scores_value                           36923 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              36923 non-null  object
#  69  calculated_host_listings_count                36923 non-null  int64
#  70  calculated_host_listings_count_entire_homes   36923 non-null  int64
#  71  calculated_host_listings_count_private_rooms  36923 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   36923 non-null  int64
#  73  reviews_per_month                             36923 non-null  float64
#  74  year                                          36923 non-null  int64
#  75  years_been_host                               36923 non-null  int64
#  76  number_of_verifications                       36923 non-null  int64
#  77  number_of_amenities                           36923 non-null  int64
#  78  geometry                                      36923 non-null  geometry
#  79  distance_ts                                   36923 non-null  float64
# dtypes: datetime64[ns](1), float64(26), geometry(1), int64(21), object(31)
# memory usage: 22.5+ MB

# %%
pd.options.display.max_rows =4000

# %%
#df['distance_ts'].value_counts()

# %%
attractions_geo = gpd.GeoDataFrame(attractions, 
                                   geometry=gpd.points_from_xy(attractions.Longitude, attractions.Latitude))

# %%
attractions_geo
# Out:
#                                     Organization Name  \
# 3                   Action Center To End World Hunger
# 4                                Circle Line Downtown
# 5                                Circle Line Downtown
# 6                                  3 Legged Dog, Inc.
# 7                    Church of Our Lady of the Rosary
# 8                                      Trinity Church
# 10                         Museum of American Finance
# 11                              Bodies The Exhibition
# 12                              Bodies The Exhibition
# 14                              The Skyscraper Museum
# 15                              The Skyscraper Museum
# 53                20 Vesey Street                       88-5
# 54              105 Nassau Street                      90-20
# 55             120 Liberty Street                      52-21
# 56                     1 Broadway                       13-1
# 58              47 Beekman Street                      93-29
# 59              47 Beekman Street                      93-29
# 60  South Street Seaport, Pier 17                      73-10
# 61               10 River Terrace                    16-7516
# 62               10 River Terrace                    16-7516
# 63               10 River Terrace                    16-7516
# 64               12 Fulton Street                       74-1
# 65               206 Front Street                       96-5
# 66         250 Greenwich Street,                       25-10
# 67           175 North End Avenue                    16-7516
# 68  South Street Seaport, Pier 17                      73-10
# 69                         Pier A                      1-Mar
#
#             Constituency Code  \
# 3                Retail Space
# 4                Retail Space
# 5          DLMA Former Member
# 6                Retail Space
# 7                Retail Space
# 8                Retail Space
# 10               Retail Space
# 11       Cultural Institution
# 12               Retail Space
# 14               Retail Space
# 15       Cultural Institution
# 16               Retail Space
# 17  Commercial Property Owner
# 18               Retail Space
# 19               Retail Space
# 21                DLMA Member
# 22                Corporation
# 23               Retail Space
# 24               Retail Space
# 25               Retail Space
# 26               Retail Space
# 29               Retail Space
# 30               Retail Space
# 33               Retail Space
# 34               Retail Space
# 35      Religious Institution
# 36               Retail Space
# 37               Retail Space
# 39               Retail Space
# 41               Retail Space
# 42               Retail Space
# 43      Religious Institution
# 44               Retail Space
# 45  Commercial Property Owner
# 46               Retail Space
# 47  Commercial Property Owner
# 48               Retail Space
# 49               Retail Space
# 50               Retail Space
# 51               Retail Space
# 52               Retail Space
# 53               Retail Space
# 54               Retail Space
# 55               Retail Space
# 56               Retail Space
# 58               Retail Space
# 59  Commercial Property Owner
# 60               Retail Space
# 61                 Non-Profit
# 62                DLMA Member
# 63               Retail Space
# 64               Retail Space
# 65               Retail Space
# 66               Retail Space
# 67               Retail Space
# 68                Corporation
# 69               Retail Space
#
#    Constituent Specific Attributes R-Secondary Type Description    Borough  \
# 3                         A-Museums & Performing Arts            Manhattan
# 4                                       V-Sightseeing            Manhattan
# 5                                       V-Sightseeing            Manhattan
# 6                                A-Theaters & Cinemas            Manhattan
# 7                            C-Religious Institutions            Manhattan
# 8                            C-Religious Institutions            Manhattan
# 10                        A-Museums & Performing Arts            Manhattan
# 11                        A-Museums & Performing Arts            Manhattan
# 12                        A-Museums & Performing Arts            Manhattan
# 14                        A-Museums & Performing Arts            Manhattan
# 15                        A-Museums & Performing Arts            Manhattan
# 16                        A-Museums & Performing Arts            Manhattan
# 17                        A-Museums & Performing Arts            Manhattan
# 18                                      V-Sightseeing            Manhattan
# 19                           C-Religious Institutions            Manhattan
# 21                                      V-Sightseeing            Manhattan
# 22                                      V-Sightseeing            Manhattan
# 23                                      V-Sightseeing            Manhattan
# 24                          A-Attractions & Landmarks            Manhattan
# 25                          A-Attractions & Landmarks            Manhattan
# 26                        A-Museums & Performing Arts            Manhattan
# 29                                      V-Sightseeing            Manhattan
# 30                               A-Theaters & Cinemas            Manhattan
# 33                           C-Religious Institutions            Manhattan
# 34                           C-Religious Institutions            Manhattan
# 35                           C-Religious Institutions            Manhattan
# 36                                   C-Public Library            Manhattan
# 37                               A-Theaters & Cinemas            Manhattan
# 39                          A-Attractions & Landmarks            Manhattan
# 41                        A-Museums & Performing Arts            Manhattan
# 42                           C-Religious Institutions            Manhattan
# 43                           C-Religious Institutions            Manhattan
# 44                           C-Religious Institutions            Manhattan
# 45                           C-Religious Institutions            Manhattan
# 46                           C-Religious Institutions            Manhattan
# 47                           C-Religious Institutions            Manhattan
# 48                                      V-Sightseeing            Manhattan
# 49                        A-Museums & Performing Arts            Manhattan
# 50                               A-Theaters & Cinemas            Manhattan
# 51                        A-Museums & Performing Arts            Manhattan
# 52                          A-Attractions & Landmarks            Manhattan
# 53                          A-Attractions & Landmarks            Manhattan
# 54                        A-Museums & Performing Arts            Manhattan
# 55                        A-Museums & Performing Arts            Manhattan
# 56                        A-Museums & Performing Arts            Manhattan
# 58                           C-Religious Institutions            Manhattan
# 59                           C-Religious Institutions            Manhattan
# 60                                      V-Sightseeing            Manhattan
# 61                        A-Museums & Performing Arts            Manhattan
# 62                        A-Museums & Performing Arts            Manhattan
# 63                        A-Museums & Performing Arts            Manhattan
# 64                        A-Museums & Performing Arts            Manhattan
# 65                          A-Attractions & Landmarks            Manhattan
# 66                           C-Religious Institutions            Manhattan
# 67                                   C-Public Library            Manhattan
# 68                                      V-Sightseeing            Manhattan
# 69                                      V-Sightseeing            Manhattan
#
#     Postcode   Latitude  Longitude  Community Board  Council District  \
# 3    10282.0  40.715781 -74.016518              1.0               1.0
# 4    10038.0  40.705717 -74.002453              1.0               1.0
# 5    10038.0  40.705717 -74.002453              1.0               1.0
# 6    10006.0  40.707514 -74.013800              1.0               1.0
# 7    10004.0  40.702398 -74.013287              1.0               1.0
# 8    10006.0  40.708387 -74.012563              1.0               1.0
# 10   10005.0  40.706331 -74.009396              1.0               1.0
# 11   10038.0  40.706639 -74.003477              1.0               1.0
# 12   10038.0  40.706639 -74.003477              1.0               1.0
# 14   10280.0  40.705869 -74.017994              1.0               1.0
# 15   10280.0  40.705869 -74.017994              1.0               1.0
# 16   10280.0  40.705806 -74.018019              1.0               1.0
# 17   10280.0  40.705806 -74.018019              1.0               1.0
# 18   10038.0  40.705717 -74.002453              1.0               1.0
# 19   10282.0  40.716668 -74.013542              1.0               1.0
# 21   10005.0  40.707399 -74.011105              1.0               1.0
# 22   10005.0  40.707399 -74.011105              1.0               1.0
# 23   10005.0  40.707399 -74.011105              1.0               1.0
# 24   10038.0  40.706916 -74.003697              1.0               1.0
# 25   10007.0  40.710967 -74.009000              1.0               1.0
# 26   10281.0  40.714120 -74.014750              1.0               1.0
# 29   10036.0  40.756087 -73.981072              5.0               4.0
# 30   10038.0  40.711909 -74.005843              1.0               1.0
# 33   10038.0  40.707981 -74.002471              1.0               1.0
# 34   10280.0  40.711329 -74.015893              1.0               1.0
# 35   10280.0  40.711329 -74.015893              1.0               1.0
# 36   10007.0  40.713314 -74.007759              1.0               1.0
# 37   10038.0  40.707712 -74.001508              1.0               1.0
# 39   10007.0  40.714807 -74.005764              1.0               1.0
# 41   10004.0  40.703496 -74.011375              1.0               1.0
# 42   10038.0  40.709254 -74.008051              1.0               1.0
# 0     105 Franklin Avenue  5.000580e+09    58.0      SI  1970-10-13
# 1  435 Richmond Hill Road  5.023900e+09  2390.0      SI  1967-12-13
# 2         98 Grant Street  5.005060e+09   506.0      SI  1996-11-19
# 3     121 Heberton Avenue  5.010150e+09  1015.0      SI  2002-12-17
# 4      3531 Richmond Road  5.022810e+09  2281.0      SI  1967-08-24
#
#      time_des_d           landmark_t    lot  \
# 0  00:00:00.000  Individual Landmark   27.0
# 1  00:00:00.000  Individual Landmark  194.0
# 2  00:00:00.000  Individual Landmark   81.0
# 3  00:00:00.000  Individual Landmark    9.0
# 4  00:00:00.000  Individual Landmark  155.0
#
#                                lpc_altern lpc_lpnumb  \
# 0     also known as Hamilton Park Cottage   LP-00330
# 1                                    None   LP-00369
# 2                                    None   LP-01877
# 3                                    None   LP-02120
# 4  also known as the Moore-McMillen House   LP-00366
#
#                                        lpc_name  \
# 0                     105 Franklin Avenue House
# 1                              Decker Farmhouse
# 2  Public School 15 (Daniel D. Tompkins School)
# 3                     121 Heberton Avenue House
# 4                    Reverend David Moore House
#
#                                           lpc_site_d  lpc_site_s  objectid  \
# 0      Borough of Richmond Tax Map Block 58, Lot 27.  Designated       1.0
# 1   Borough of Richmond Tax Map Block 2390, Lot 194.  Designated       2.0
# 2  Borough of Staten Island Tax Map Block 506, Lo...  Designated       3.0
# 3  Borough of the Staten Island Tax Map Block 101...  Designated       4.0
# 4   Borough of Richmond Tax Map Block 2282, Lot 155.  Designated       5.0
#
#    objectid_1     shape_area   shape_leng  \
# 0         1.0   11078.250002   446.281129
# 1         2.0  484779.747763  2797.209417
# 2         3.0   32265.596414   748.859029
# 3         4.0    6515.861133   329.167837
# 4         5.0   34036.911836   775.778936
#
#                                         url_report  \
# 0  http://s-media.nyc.gov/agencies/lpc/lp/0330.pdf
# 1  http://s-media.nyc.gov/agencies/lpc/lp/0369.pdf
# 2  http://s-media.nyc.gov/agencies/lpc/lp/1877.pdf
# 3  http://s-media.nyc.gov/agencies/lpc/lp/2120.pdf
# 4  http://s-media.nyc.gov/agencies/lpc/lp/0366.pdf
#
#                                             geometry
# 0  POLYGON ((-74.09145 40.64303, -74.09142 40.642...
# 1  POLYGON ((-74.15192 40.58296, -74.15200 40.582...
# 2  POLYGON ((-74.07791 40.63379, -74.07805 40.633...
# 3  POLYGON ((-74.13067 40.63717, -74.13072 40.636...
# 4  POLYGON ((-74.13863 40.57340, -74.13829 40.572...

# %%
map_df2.plot()
# Out:
# <AxesSubplot:>

# %%
poi = pd.read_csv('/Users/raylinsoriano/Documents/Flatiron/capstone/data/Point_Of_Interest.csv')

# %%
#poi.head(10)

# %%
geo_df2 = gpd.read_file('/Users/raylinsoriano/Documents/Flatiron/capstone/data/attraction_polygon.geojson')

# %%
geo_df2.shape
# Out:
# (67, 123)

# %%
pd.options.display.max_rows =4000

# %%
geo_df2
# Out:
#        tourism                                    name       building  \
# 0   attraction               Abyssinian Baptist Church            yes
# 1   attraction                     Aermacchi MB339 PAN            yes
# 2   attraction                            Amazen' Maze           None
# 3   attraction                                 Ambrose           None
# 4   attraction                         Blackwell House            yes
# 5   attraction                              Bow Bridge           None
# 6   attraction                         Brooklyn Bridge           None
# 7   attraction                             Bryant Park           None
# 8   attraction                          Castle Clinton            yes
# 9   attraction      Cathedral of Saint John the Divine            yes
# 10  attraction                   Central Park Carousel            yes
# 11  attraction                         Columbus Circle           None
# 12  attraction                                Concorde            yes
# 13  attraction                             E-1B Tracer            yes
# 14  attraction                   Empire State Building         office
# 15  attraction                             F-14 Tomcat            yes
# 16  attraction                   F-16A Fighting Falcon            yes
# 17  attraction                         F-4N Phantom II            yes
# 18  attraction                           F/A-18 Hornet            yes
# 19  attraction                           FDNY Ladder 8   fire_station
# 20  attraction          Federal Hall National Memorial            yes
# 21  attraction                 Fireboat John J. Harvey           None
# 22  attraction                       Flatiron Building         office
# 23  attraction                                Fort Jay           None
# 24  attraction                  Grand Central Terminal  train_station
# 25  attraction                        Helen McAllister           None
# 26  attraction                     HH-52A Sea Guardian            yes
# 27  attraction             Hispanic Society of America           None
# 28  attraction                                Kfir C-2            yes
# 29  attraction                    Lightship Frying Pan           None
# 30  attraction  Lincoln Center for the Performing Arts           None
# 31  attraction                           Lockheed A-12            yes
# 32  attraction                   Madison Square Garden            yes
# 33  attraction                                  MiG-17            yes
# 34  attraction                                  MiG-21            yes
# 35  attraction           New York City Police Memorial           None
# 36  attraction                 New York Public Library        library
# 37  attraction                 New York Stock Exchange            yes
# 38  attraction             Ripley's Believe It or Not!           None
# 39  attraction                      Rockefeller Center           None
# 40  attraction                     Saint Paul's Chapel         church
# 41  attraction                       Saks Fifth Avenue            yes
# 42  attraction                         Sherman Zwicker           None
# 43  attraction                Space Shuttle Enterprise            yes
# 44  attraction                       Statue of Liberty            yes
# 45  attraction                          The Blockhouse            yes
# 46  attraction                           The Cloisters            yes
# 47  attraction                              The Dakota     apartments
# 48  attraction                      The Drawing Center            yes
# 49  attraction                       Times Square Ball           None
# 50  attraction             United Nations Headquarters         office
# 51  attraction                             USCGC Lilac           None
# 52  attraction                             USS Growler      submarine
# 53  attraction                            USS Intrepid           ship
# 54  attraction                               Wavertree           None
# 55  attraction                      Woolworth Building            yes
# 56  attraction                                    None            yes
# 57  attraction                                    None            yes
# 58  attraction                                    None            yes
# 59  attraction                                    None            yes
# 60  attraction                                    None            yes
# 61  attraction                                    None            yes
# 62  attraction                                    None            yes
# 63  attraction                                    None            yes
# 64  attraction                                    None            yes
# 65  attraction                                    None            yes
# 66  attraction                                    None           None
#
#      wikidata                                       wikipedia    historic  \
# 0      Q49254                                            None        None
# 1        None                                            None    aircraft
# 2        None                                            None        None
# 3    Q7890707      en:United States lightship Ambrose (LV-87)        ship
# 4    Q4923596                              en:Blackwell House         yes
# 5    Q4950616                    en:Bow Bridge (Central Park)        None
# 6     Q125006                              en:Brooklyn Bridge        None
# 7     Q995174                                  en:Bryant Park        None
# 8    Q1049423                               en:Castle Clinton         yes
# 9     Q865655           en:Cathedral of Saint John the Divine        None
# 10   Q5061605                        en:Central Park Carousel        None
# 11       None                                            None        None
# 12      Q6505                                     en:Concorde    aircraft
# 13       None                                            None    aircraft
# 14      Q9188                        en:Empire State Building        None
# 15       None                                            None    aircraft
# 16       None                                            None    aircraft
# 17       None                                            None    aircraft
# 18       None                                            None    aircraft
# 19  Q21712009           en:Firehouse, Hook & Ladder Company 8        None
# 20    Q858689                                 en:Federal Hall        None
# 21   Q6241091                               en:John J. Harvey        ship
# 22    Q220728                            en:Flatiron Building        None
# 23   Q5471408                                     en:Fort Jay        fort
# 24     Q11290                       en:Grand Central Terminal        None
# 25   Q4683669                      en:Admiral Dewey (tugboat)        ship
# 26       None                                            None  helicopter
# 27   Q2420849                                            None        None
# 28       None                                            None    aircraft
# 29    Q588285  en:United States lightship Frying Pan (LV-115)        ship
# 30    Q581044       en:Lincoln Center for the Performing Arts        None
# 31    Q959030                                en:Lockheed A-12    aircraft
# 32    Q186125                        en:Madison Square Garden        None
# 33       None                                            None    aircraft
# 34       None                                            None    aircraft
# 35       None                                            None    memorial
# 36   Q7013887                      en:New York Public Library        None
# 37     Q13677                      en:New York Stock Exchange        None
# 38       None                                            None        None
# 39     Q11277                           en:Rockefeller Center         yes
# 40   Q1325500                            en:St. Paul's Chapel        None
# 41   Q2723882                            en:Saks Fifth Avenue        None
# 42       None                              en:Sherman Zwicker        ship
# 43    Q202347                     en:Space Shuttle Enterprise    aircraft
# 44      Q9202                            en:Statue of Liberty    monument
# 45   Q4927275              en:Blockhouse No. 1 (Central Park)    building
# 46   Q1138030                                en:The Cloisters        None
# 47    Q829806                                   en:The Dakota    building
# 48   Q3039170                                            None        None
# 49   Q1058395                            en:Times Square Ball        None
# 50     Q11297           en:Headquarters of the United Nations        None
# 51       None                       en:USCGC Lilac (WAGL-227)        ship
# 52    Q629738                        en:USS Growler (SSG-577)        ship
# 53   Q1351288                         en:USS Intrepid (CV-11)        ship
# 54   Q2552894                             en:Wavertree (ship)        ship
# 55    Q217652                           en:Woolworth Building        None
# 56       None                                            None    aircraft
# 57       None                                            None    aircraft
# 58       None                                            None    aircraft
# 59       None                                            None    aircraft
# 60       None                                            None    aircraft
# 61       None                                            None    aircraft
# 62       None                                            None    aircraft
# 63       None                                            None  helicopter
# 64       None                                            None  helicopter
# 65       None                                            None  helicopter
# 66       None                                            None        None
#
#     start_date layer                                            website  \
# 0         None  None                                               None
# 1         None     3                                               None
# 2         None  None               https://www.adventuresgovisland.com/
# 3         1907  None                                               None
# 4         None  None                                               None
# 5         None     1  https://www.centralpark.com/things-to-do/attra...
# 6         None     3                                               None
# 7         None  None                          http://www.bryantpark.org
# 8         None  None                                               None
# 9         None  None                      https://www.stjohndivine.org/
# 10        None  None  www.centralparknyc.org/things-to-see-and-do/at...
# 11        None  None                                               None
# 12        None     2                                               None
# 13        None     3                                               None
# 14        1931  None                     https://www.esbnyc.com/explore
# 15        None     3                                               None
# 16        None     3                                               None
# 17        None     3                                               None
# 18        None     3                                               None
# 19        None  None                                               None
# 20        1842  None                           https://www.nps.gov/feha
# 21        1931  None                           http://www.fireboat.org/
# 22        1902  None                                               None
# 23        1794     1                                               None
# 24        1913  None              https://www.grandcentralterminal.com/
# 25        1900  None                                               None
# 26        None     3                                               None
# 27        None  None                                               None
# 28        None     3                                               None
# 29        1929  None                          http://www.fryingpan.com/
# 30        None  None                                               None
# 31        None     3                                               None
# 32        1968  None                          http://www.thegarden.com/
# 33        None     3                                               None
# 34        None     3                                               None
# 35        1997  None                                               None
# 36        None  None                               http://www.nypl.org/
# 37        1922  None                                               None
# 38        None  None                         https://ripleysnewyork.com
# 39        None  None                 https://www.rockefellercenter.com/
# 40        1766  None  https://www.trinitywallstreet.org/congregation...
# 41        1924  None                   https://www.saksfifthavenue.com/
# 42        1942  None        https://www.grandbanks.nyc/sherman-zwicker/
# 43        1977     3                                               None
# 44  1886-10-28  None                                               None
# 45        1814  None  http://www.centralparknyc.org/things-to-see-an...
# 46        None  None                 http://www.metmuseum.org/cloisters
# 47        1882  None                                               None
# 48        None  None                                               None
# 49        1907  None                                               None
# 50        1952  None                                https://www.un.org/
# 51        1933  None           http://www.lilacpreservationproject.org/
# 52        1958     1                                               None
# 53        1943     2                                               None
# 54        1885  None                                               None
# 55        1913  None                                               None
# 56        None     3                                               None
# 57        None     3                                               None
# 58        None     3                                               None
# 59        None     3                                               None
# 60        None     3                                               None
# 61        None     3                                               None
# 62        None     3                                               None
# 63        None     3                                               None
# 64        None     3                                               None
# 65        None     3                                               None
# 66        None  None                                               None
#
#    addr:housenumber  ...              shop short_name:de short_name:es  \
# 0               132  ...              None          None          None
# 1              None  ...              None          None          None
# 2              None  ...              None          None          None
# 3              None  ...              None          None          None
# 4               500  ...              None          None          None
# 5              None  ...              None          None          None
# 6              None  ...              None          None          None
# 7              None  ...              None          None          None
# 8                10  ...              None          None          None
# 9              1047  ...              None          None          None
# 10             None  ...              None          None          None
# 11             None  ...              None          None          None
# 12             None  ...              None          None          None
# 13             None  ...              None          None          None
# 14              350  ...              None          None          None
# 15             None  ...              None          None          None
# 16             None  ...              None          None          None
# 17             None  ...              None          None          None
# 18             None  ...              None          None          None
# 19               14  ...              None          None          None
# 20             None  ...              None          None          None
# 21             None  ...              None          None          None
# 22              175  ...              None          None          None
# 23             None  ...              None          None          None
# 24               89  ...              None          None          None
# 25             None  ...              None          None          None
# 26             None  ...              None          None          None
# 27             None  ...              None          None          None
# 28             None  ...              None          None          None
# 29             None  ...              None          None          None
# 30               10  ...              None          None          None
# 31             None  ...              None          None          None
# 32               46  ...              None          None          None
# 33             None  ...              None          None          None
# 34             None  ...              None          None          None
# 35             None  ...              None          None          None
# 36              476  ...              None          None          None
# 37               11  ...              None          None          None
# 38              234  ...              None          None          None
# 39               45  ...              None          None          None
# 40              209  ...              None          None          None
# 41              611  ...  department_store          None          None
# 42             None  ...              None          None          None
# 43             None  ...              None          None          None
# 44             None  ...              None          None          None
# 45             None  ...              None          None          None
# 46             None  ...              None          None          None
# 47                1  ...              None          None          None
# 48               35  ...              None          None          None
# 49             None  ...              None          None          None
# 50              405  ...              None            VN           ONU
# 51             None  ...              None          None          None
# 52             None  ...              None          None          None
# 53                1  ...              None          None          None
# 54             None  ...              None          None          None
# 55             None  ...              None          None          None
# 56             None  ...              None          None          None
# 57             None  ...              None          None          None
# 58             None  ...              None          None          None
# 59             None  ...              None          None          None
# 60             None  ...              None          None          None
# 61             None  ...              None          None          None
# 62             None  ...              None          None          None
# 63             None  ...              None          None          None
# 64             None  ...              None          None          None
# 65             None  ...              None          None          None
# 66             None  ...              None          None          None
#
#    short_name:fr  sport sub_sea              team           team_2 train  \
# 0           None   None    None              None             None  None
# 1           None   None    None              None             None  None
# 2           None   None    None              None             None  None
# 3           None   None    None              None             None  None
# 4           None   None    None              None             None  None
# 5           None   None    None              None             None  None
# 6           None   None    None              None             None  None
# 7           None   None    None              None             None  None
# 8           None   None    None              None             None  None
# 9           None   None    None              None             None  None
# 10          None   None    None              None             None  None
# 11          None   None    None              None             None  None
# 12          None   None    None              None             None  None
# 13          None   None    None              None             None  None
# 14          None   None    None              None             None  None
# 15          None   None    None              None             None  None
# 16          None   None    None              None             None  None
# 17          None   None    None              None             None  None
# 18          None   None    None              None             None  None
# 19          None   None    None              None             None  None
# 20          None   None    None              None             None  None
# 21          None   None    None              None             None  None
# 22          None   None    None              None             None  None
# 23          None   None    None              None             None  None
# 24          None   None    None              None             None   yes
# 25          None   None    None              None             None  None
# 26          None   None    None              None             None  None
# 27          None   None    None              None             None  None
# 28          None   None    None              None             None  None
# 29          None   None    None              None             None  None
# 30          None   None    None              None             None  None
# 31          None   None    None              None             None  None
# 32          None  multi    None  New York Rangers  New York Knicks  None
# 33          None   None    None              None             None  None
# 34          None   None    None              None             None  None
# 35          None   None    None              None             None  None
# 36          None   None    None              None             None  None
# 37          None   None    None              None             None  None
# 38          None   None    None              None             None  None
# 39          None   None    None              None             None  None
# 40          None   None    None              None             None  None
# 41          None   None    None              None             None  None
# 42          None   None    None              None             None  None
# 43          None   None    None              None             None  None
# 44          None   None    None              None             None  None
# 45          None   None    None              None             None  None
# 46          None   None    None              None             None  None
# 47          None   None    None              None             None  None
# 48          None   None    None              None             None  None
# 49          None   None    None              None             None  None
# 50           ONU   None    None              None             None  None
# 51          None   None    None              None             None  None
# 52          None   None     yes              None             None  None
# 53          None   None    None              None             None  None
# 54          None   None    None              None             None  None
# 55          None   None    None              None             None  None
# 56          None   None    None              None             None  None
# 57          None   None    None              None             None  None
# 58          None   None    None              None             None  None
# 59          None   None    None              None             None  None
# 60          None   None    None              None             None  None
# 61          None   None    None              None             None  None
# 62          None   None    None              None             None  None
# 63          None   None    None              None             None  None
# 64          None   None    None              None             None  None
# 65          None   None    None              None             None  None
# 66          None   None    None              None             None  None
#
#                                              geometry
# 0   POLYGON ((-73.94179 40.81662, -73.94149 40.816...
# 1   POLYGON ((-74.00122 40.76502, -74.00119 40.765...
# 2   POLYGON ((-74.02106 40.68999, -74.02091 40.689...
# 3   POLYGON ((-74.00262 40.70545, -74.00262 40.705...
# 4   POLYGON ((-73.95125 40.76028, -73.95119 40.760...
# 5   POLYGON ((-73.97193 40.77592, -73.97166 40.775...
# 6   POLYGON ((-74.00436 40.71193, -74.00288 40.710...
# 7   POLYGON ((-73.98480 40.75357, -73.98310 40.752...
# 55  POLYGON ((-74.00877 40.71242, -74.00817 40.712...
# 56  POLYGON ((-74.00083 40.76490, -74.00079 40.764...
# 57  POLYGON ((-74.00001 40.76429, -74.00000 40.764...
# 58  POLYGON ((-73.99985 40.76422, -73.99982 40.764...
# 59  POLYGON ((-74.00044 40.76453, -74.00044 40.764...
# 60  POLYGON ((-74.00055 40.76469, -74.00053 40.764...
# 61  POLYGON ((-74.00057 40.76486, -74.00056 40.764...
# 62  POLYGON ((-74.00090 40.76494, -74.00089 40.764...
# 63  POLYGON ((-74.00033 40.76462, -74.00033 40.764...
# 64  POLYGON ((-74.00038 40.76462, -74.00037 40.764...
# 65  POLYGON ((-74.00043 40.76464, -74.00042 40.764...
# 66  POLYGON ((-74.00609 40.70407, -74.00606 40.704...
#
# [67 rows x 123 columns]

# %%
df.shape
# Out:
# (36923, 80)

# %%
attractions.head()
# Out:
#                    Organization Name       Preferred Address Line 1  \
# 3  Action Center To End World Hunger                6 River Terrace
# 4               Circle Line Downtown  South Street Seaport, Pier 17
# 5               Circle Line Downtown  South Street Seaport, Pier 17
# 6                 3 Legged Dog, Inc.            80 Greenwich Street
# 7   Church of Our Lady of the Rosary               7-8 State Street
#
#   Preferred Block-Lot Number   Constituency Code  \
# 3                     16-270        Retail Space
# 4                    15-7501        Retail Space
# 5                    15-7501  DLMA Former Member
# 6                     18-100        Retail Space
# 7                      7-Sep        Retail Space
#
#   Constituent Specific Attributes R-Secondary Type Description    Borough  \
# 3                        A-Museums & Performing Arts            Manhattan
# 4                                      V-Sightseeing            Manhattan
# 5                                      V-Sightseeing            Manhattan
# 6                               A-Theaters & Cinemas            Manhattan
# 7                           C-Religious Institutions            Manhattan
#
#    Postcode   Latitude  Longitude  Community Board  Council District  \
# 3   10282.0  40.715781 -74.016518              1.0               1.0
# 4   10038.0  40.705717 -74.002453              1.0               1.0
# 5   10038.0  40.705717 -74.002453              1.0               1.0
# 6   10006.0  40.707514 -74.013800              1.0               1.0
# 7   10004.0  40.702398 -74.013287              1.0               1.0
#
#    Census Tract        BIN           BBL  \
# 3       31703.0  1087518.0  1.000168e+09
# 4        1501.0  1000000.0  1.000730e+09
# 5        1501.0  1000000.0  1.000730e+09
# 6          13.0  1078977.0  1.000180e+09
# 7           9.0  1000019.0  1.000090e+09
#
#                                                  NTA  \
# 3  Battery Park City-Lower Manhattan             ...
# 4  Battery Park City-Lower Manhattan             ...
# 5  Battery Park City-Lower Manhattan             ...
# 6  Battery Park City-Lower Manhattan             ...
# 7  Battery Park City-Lower Manhattan             ...
#
#                      geometry
# 3  POINT (-74.01652 40.71578)
# 4  POINT (-74.00245 40.70572)
# 5  POINT (-74.00245 40.70572)
# 6  POINT (-74.01380 40.70751)
# 7  POINT (-74.01329 40.70240)

# %%
attractions.rename(columns={"Organization Name": "organization_name"}, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'years_been_host', 'number_of_verifications',
#        'number_of_amenities', 'geometry', 'distance_ts'],
#       dtype='object')

# %%
# concatenating lat and long to create a consolidated location as accepted by havesine function
attractions['coor'] = list(zip(attractions.Latitude, attractions.Longitude))
df['coor'] = list(zip(df.latitude, df.longitude))

# %%
attractions.head()
# Out:
#                    organization_name       Preferred Address Line 1  \
# 3  Action Center To End World Hunger                6 River Terrace
# 4               Circle Line Downtown  South Street Seaport, Pier 17
# 5               Circle Line Downtown  South Street Seaport, Pier 17
# 6                 3 Legged Dog, Inc.            80 Greenwich Street
# 7   Church of Our Lady of the Rosary               7-8 State Street
#
#   Preferred Block-Lot Number   Constituency Code  \
# 3                     16-270        Retail Space
# 4                    15-7501        Retail Space
# 5                    15-7501  DLMA Former Member
# 6                     18-100        Retail Space
# 7                      7-Sep        Retail Space
#
#   Constituent Specific Attributes R-Secondary Type Description    Borough  \
# 3                        A-Museums & Performing Arts            Manhattan
# 4                                      V-Sightseeing            Manhattan
# 5                                      V-Sightseeing            Manhattan
# 6                               A-Theaters & Cinemas            Manhattan
# 7                           C-Religious Institutions            Manhattan
#
#    Postcode   Latitude  Longitude  Community Board  Council District  \
# 3   10282.0  40.715781 -74.016518              1.0               1.0
# 4   10038.0  40.705717 -74.002453              1.0               1.0
# 5   10038.0  40.705717 -74.002453              1.0               1.0
# 6   10006.0  40.707514 -74.013800              1.0               1.0
# 7   10004.0  40.702398 -74.013287              1.0               1.0
#
#    Census Tract        BIN           BBL  \
# 3       31703.0  1087518.0  1.000168e+09
# 4        1501.0  1000000.0  1.000730e+09
# 5        1501.0  1000000.0  1.000730e+09
# 6          13.0  1078977.0  1.000180e+09
# 7           9.0  1000019.0  1.000090e+09
#
#                                                  NTA  \
# 3  Battery Park City-Lower Manhattan             ...
# 4  Battery Park City-Lower Manhattan             ...
# 5  Battery Park City-Lower Manhattan             ...
# 6  Battery Park City-Lower Manhattan             ...
# 7  Battery Park City-Lower Manhattan             ...
#
#                      geometry                     coor
# 3  POINT (-74.01652 40.71578)  (40.715781, -74.016518)
# 4  POINT (-74.00245 40.70572)  (40.705717, -74.002453)
# 5  POINT (-74.00245 40.70572)  (40.705717, -74.002453)
# 6  POINT (-74.01380 40.70751)    (40.707514, -74.0138)
# 7  POINT (-74.01329 40.70240)  (40.702398, -74.013287)

# %%
import pandas as pd
import numpy as np
import haversine as hs
import folium

# %%
def distance_from(loc1,loc2): 
    dist=hs.haversine(loc1,loc2)
    return round(dist,2)

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20210901220703   2021-09-02
# 1  3831  https://www.airbnb.com/rooms/3831  20210901220703   2021-09-02
# 2  5121  https://www.airbnb.com/rooms/5121  20210901220703   2021-09-02
# 3  5136  https://www.airbnb.com/rooms/5136  20210901220703   2021-09-02
# 4  5178  https://www.airbnb.com/rooms/5178  20210901220703   2021-09-02
#
#                                                 name  \
# 0                              Skylit Midtown Castle
# 1  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                    BlissArtsSpace!
# 3           Spacious Brooklyn Duplex, Patio + Garden
# 4                   Large Furnished Room Near B'way
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 2  <b>The space</b><br />HELLO EVERYONE AND THANK...
# 3  We welcome you to stay in our lovely 2 br dupl...
# 4  Please don’t expect the luxury here just a bas...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Just the right mix of urban center and local n...
# 2  The Greenpoint House in only a few short block...
# 3  The Greenpoint House in only a few short block...
# 4    Theater district, many restaurants around here.
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845
# 1  https://a0.muscache.com/pictures/e49999c2-9fd5...     4869
# 2  https://a0.muscache.com/pictures/2090980c-b68e...     7356
# 3  https://a0.muscache.com/pictures/miso/Hosting-...     7378
# 4  https://a0.muscache.com/pictures/12065/f070997...     8967
#
#                                  host_url  ...  \
# 0  https://www.airbnb.com/users/show/2845  ...
# 1  https://www.airbnb.com/users/show/4869  ...
# 2  https://www.airbnb.com/users/show/7356  ...
# 3  https://www.airbnb.com/users/show/7378  ...
# 4  https://www.airbnb.com/users/show/8967  ...
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  year  \
# 0                                           0              0.33  2008
# 1                                           0              5.03  2008
# 2                                           0              0.54  2009
# 3                                           0              0.02  2009
# 4                                           0              3.64  2009
#
#   years_been_host number_of_verifications number_of_amenities  \
# 0              13                       9                  31
# 1              13                       6                  35
# 2              12                       8                   5
# 3              12                       3                  14
# 4              12                       4                  19
#
#                      geometry   distance_ts                   coor
# 0  POINT (-73.98559 40.75356)  10392.674145  (40.75356, -73.98559)
# 1  POINT (-73.95765 40.68494)  10413.322858  (40.68494, -73.95765)
# 2  POINT (-73.95512 40.68535)  10413.107801  (40.68535, -73.95512)
# 3  POINT (-73.99454 40.66265)  10421.591992  (40.66265, -73.99454)
# 4  POINT (-73.98317 40.76457)  10390.587498  (40.76457, -73.98317)
#
# [5 rows x 81 columns]

# %%
`
# Out:
#   File "/var/folders/10/1w2hpkhn2v9g5h3_0k0f70t40000gn/T/ipykernel_34004/473536216.py", line 1
#     `
#     ^
# SyntaxError: invalid syntax

# %%
# running a loop which will parse customers location one by one to distance from function 
for _,row in attractions.iterrows():
    df[row.organization_name]= df['coor'].apply(lambda x: distance_from(row.coor,x))

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        ...
#        'Tribute WTC', 'Center for Castle Garden Immigration',
#        'Wall Street Synagogue', 'Manhattan By Sail', 'Poets House',
#        'South Street Seaport Museum', 'Cannon's Walk',
#        'The River Vineyard Christian Fellowship', 'Bike & Roll Bike Rentals',
#        'NY Waterway Tours'],
#       dtype='object', length=124)

# %%
def create_map(df,attractions):
    m = folium.Map(location=[df.latitude.mean(), df.longitude.mean()], zoom_start=12, tiles='OpenStreetMap')
    
   
    
    for _, row in df.iterrows():
         
        if row['Condition']=='Out':
            cluster_colour='blue'
        else:
            cluster_colour = 'green'
        
        folium.CircleMarker(
            location= [row['latitude'],row['longitude']],
            radius=5,
            popup= row[['Condition','id']],
            color=cluster_colour,
            fill=True,
            fill_color=cluster_colour
            ).add_to(m)
    
    for _, row in attractions.iterrows(): 
        folium.Marker(
            location= [row['Latitude'],row['Longitude']],
            radius=5,
            popup= row['Organization Name'],
            color='red',
            fill=True,
            fill_color='red'
             ).add_to(m)
    for _, row in attractions.iterrows(): 
        folium.Circle(
            location= [row['Latitude'],row['Longitude']],
            radius=100,
            popup= row['Organization Name'],
            color='black',
            fill=False,
        ).add_to(m)
        
    return m

# %%
#hotel_list=[60,61]

# %%
# df['Condition']='Out'

# for i in hotel_list:
#     df['Condition'][df.Condition=='Out']=df[df.Condition=='Out'][i].apply(lambda x: 'In' if x<3 else 'Out')

# %%
# m= create_map(df,attractions)
# m

# %%
#df['Condition']

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.boxplot(x="has_availability", y="number_of_amenities", data=df)

# %%
df['amenities']
# Out:
# 0        ["Free street parking", "Heating", "TV", "Dedi...
# 1        ["Dedicated workspace", "Iron", "Stove", "Hair...
# 2        ["Kitchen", "Long term stays allowed", "Air co...
# 3        ["Dryer", "BBQ grill", "Kitchen", "Long term s...
# 4        ["Hot water", "Bed linens", "Extra pillows and...
#                                ...
# 36918    ["Dedicated workspace", "Essentials", "Microwa...
# 36919    ["Heating", "TV", "Freezer", "Toaster", "Trash...
# 36920    ["Dedicated workspace", "Stove", "Washer", "Ha...
# 36921    ["Heating", "TV", "Freezer", "Toaster", "Trash...
# 36922    ["Kitchen", "Washer", "Smoke alarm", "Heating"...
# Name: amenities, Length: 36923, dtype: object

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.boxplot(x="has_availability", y="number_of_amenities", data=df)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.barplot(x="has_availability", y="number_of_reviews", data=df)

# %%
sns.set(rc = {'figure.figsize':(10,8)})
ax2 = sns.catplot(x="has_availability", y="number_of_reviews", data=df)

# %%
# counter = []
# for x in df['instant_bookable']:
#     if x == 't':
#         counter[x+1]

# %%
df.instant_bookable.value_counts()
# Out:
# f    27063
# t     9860
# Name: instant_bookable, dtype: int64

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.barplot(x="has_availability", y=df.instant_bookable.value_counts(), data=df)

# %%
plt.figure(figsize=(13,7))
plt.title("instant_bookable")
host_response_time_graph = sns.countplot(df.instant_bookable, palette="muted")
host_response_time_graph.set_xlabel("instant_bookable")
fig = plt.gcf()
plt.show()
# Out:
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['instant_bookable']
# Out:
# 0        f
# 1        f
# 2        f
# 3        f
# 4        f
#         ..
# 36918    t
# 36919    f
# 36920    f
# 36921    f
# 36922    f
# Name: instant_bookable, Length: 36923, dtype: object

# %%
fake_df = pd.get_dummies(df,columns=['instant_bookable'])

# %%
fake_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        ...
#        'Wall Street Synagogue', 'Manhattan By Sail', 'Poets House',
#        'South Street Seaport Museum', 'Cannon's Walk',
#        'The River Vineyard Christian Fellowship', 'Bike & Roll Bike Rentals',
#        'NY Waterway Tours', 'instant_bookable_f', 'instant_bookable_t'],
#       dtype='object', length=125)

# %%
fake_df["instant_bookable_f"].sum()
# Out:
# 27063

# %%
df['instant_bookable'] == 't'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36918     True
# 36919    False
# 36920    False
# 36921    False
# 36922    False
# Name: instant_bookable, Length: 36923, dtype: bool

# %%
# sns.set(rc = {'figure.figsize':(15,8)})
# ax = sns.barplot(x="has_availability", y=df.instant_bookable, data=df)

# %%
fake_df.instant_bookable_f
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 36918    0
# 36919    1
# 36920    1
# 36921    1
# 36922    1
# Name: instant_bookable_f, Length: 36923, dtype: uint8

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.barplot(x="has_availability", y=fake_df.instant_bookable_f, data=fake_df)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.barplot(x="has_availability", y=fake_df.instant_bookable_t, data=fake_df)

# %%
#ok = df.groupby('has_availability',axis=1).instant_bookable.agg(lambda g: g.eq('f').sum())

# %%
ok
# Out:
# has_availability
# f     2132
# t    24931
# Name: instant_bookable, dtype: int64

# %%
okkk = pd.get_dummies(df, columns=['instant_bookable']).groupby('has_availability').sum()

# %%
okkk.reset_index()
# Out:
#   has_availability            id           scrape_id        host_id  \
# 0                f   31922584528   43089641402538800   105778823437
# 1                t  994173125148  703157464369478016  3860946981643
#
#    host_listings_count  host_total_listings_count      latitude     longitude  \
# 0               2605.0                     2605.0  8.683991e+04 -1.576746e+05
# 1            1203814.0                  1203814.0  1.417009e+06 -2.572765e+06
#
#    accommodates  bathrooms  ...  Wall Street Synagogue  Manhattan By Sail  \
# 0          4528        0.0  ...               15281.24           15322.87
# 1         98767        0.0  ...              271279.01          271213.02
#
#    Poets House  South Street Seaport Museum  Cannon's Walk  \
# 0     16237.58                     15352.68       15292.00
# 1    287772.33                    271854.26      270918.43
#
#    The River Vineyard Christian Fellowship  Bike & Roll Bike Rentals  \
# 0                                 15802.51                  15322.87
# 1                                280314.41                 271213.02
#
#    NY Waterway Tours  instant_bookable_f  instant_bookable_t
# 0           17070.61              2132.0                 0.0
# 1          299883.68             24931.0              9860.0
#
# [2 rows x 93 columns]

# %%
pp = pd.crosstab(fake_df.has_availability, fake_df.instant_bookable_f).reset_index()

# %%
categories = fake_df['has_availability'].value_counts().index
counts = fake_df['instant_bookable_t'].value_counts().values
plt.bar(categories, counts, width=0.5);
# Out:
# <BarContainer object of 2 artists>

# %%
categories = df['has_availability'].value_counts().index
counts = fake_df['instant_bookable_t'].value_counts().values
plt.bar(categories, counts, width=0.5)

# %%
df = df.drop(['host_url','listing_url', 'picture_url','host_thumbnail_url', 'host_picture_url','neighbourhood'
              ,'host_neighbourhood','property_type','bathrooms', 'minimum_minimum_nights', 'maximum_minimum_nights'
             ,'minimum_maximum_nights','maximum_maximum_nights', 'minimum_nights_avg_ntm','maximum_nights_avg_ntm'
             ,'calendar_updated','calendar_last_scraped', 'number_of_reviews_ltm', 'number_of_reviews_l30d'
             ,'first_review','last_review', 'review_scores_value','license','reviews_per_month', 'neighborhood_overview'
             ,'host_response_rate', 'host_acceptance_rate','host_about', 'host_location', 'scrape_id','last_scraped'
             ,'host_since','year', 'neighbourhood_cleansed', 'amenities','host_name', 'name', 'host_id', 'description'
             ,'geometry', 'coor'
             
             ], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36923 entries, 0 to 36922
# Columns: 142 entries, id to NY Waterway Tours
# dtypes: float64(115), int64(17), object(10)
# memory usage: 40.0+ MB

# %%
df.isna().sum()
# Out:
# id                                              0
# host_response_time                              0
# host_is_superhost                               0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood_group_cleansed                    0
# latitude                                        0
# longitude                                       0
# room_type                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# years_been_host                                 0
# number_of_verifications                         0
# number_of_amenities                             0
# distance_ts                                     0
# 3                                               0
# 4                                               0
# 5                                               0
# 6                                               0
# 7                                               0
# 8                                               0
# 10                                              0
# 11                                              0
# 12                                              0
# 14                                              0
# 15                                              0
# 16                                              0
# 17                                              0
# 18                                              0
# 19                                              0
# 21                                              0
# 22                                              0
# 23                                              0
# 24                                              0
# 25                                              0
# 26                                              0
# 29                                              0
# 30                                              0
# 33                                              0
# 34                                              0
# 35                                              0
# 36                                              0
# 37                                              0
# 39                                              0
# 41                                              0
# 42                                              0
# 43                                              0
# 44                                              0
# 45                                              0
# 46                                              0
# 47                                              0
# 48                                              0
# 49                                              0
# 50                                              0
# 51                                              0
# 52                                              0
# 53                                              0
# 54                                              0
# 55                                              0
# 56                                              0
# 58                                              0
# 59                                              0
# 60                                              0
# 61                                              0
# 62                                              0
# 63                                              0
# 64                                              0
# 65                                              0
# 66                                              0
# 67                                              0
# 68                                              0
# 69                                              0
# Condition                                       0
# dtype: int64

# %%
df['has_availability'].value_counts()
# Out:
# t    34791
# f     2132
# Name: has_availability, dtype: int64

# %%
df['has_availability'].value_counts(normalize=True)
# Out:
# t    0.942258
# f    0.057742
# Name: has_availability, dtype: float64

# %%
df['has_availability'] = df['has_availability'].map({'t': 0,
                                     'f': 1,})

# %%
X= df.drop(["has_availability",'id', 'latitude','longitude'],axis=1)
y= df["has_availability"]

X_train, X_test, y_train, y_test= train_test_split(X, y, stratify=y)

# %%
#Categorical variables to use
categorical_vars = ["host_response_time","host_has_profile_pic","host_identity_verified","host_is_superhost"
            ,"neighbourhood_group_cleansed","room_type","instant_bookable", "Condition"]

# %%
train = X_train[categorical_vars]

# Create OneHotEncoder object to create dummies
ohe = OneHotEncoder(handle_unknown='ignore')
enc = ohe.fit(train)
train_dummies_trans = enc.transform(train)

# Dummies values in matrix form
train_data = train_dummies_trans.todense()

# New dummy column names
names = ohe.get_feature_names(categorical_vars)

# Make them into Dataframe
train_dummies_trans_df = pd.DataFrame(train_data, columns=names,index = X_train.index)

# %%
test = X_test[categorical_vars]
    
# Create OneHotEncoder object to create dummies
ohe = OneHotEncoder(handle_unknown='ignore')
enc = ohe.fit(test)
test_dummies_trans = enc.transform(test)

# Dummies values in matrix form
test_data = test_dummies_trans.todense()

# New dummy column names
names1 = ohe.get_feature_names(categorical_vars)

# Make them into Dataframe
test_dummies_trans_df = pd.DataFrame(test_data, columns=names1,index = X_test.index)

# %%
numerical = (X_train.select_dtypes(exclude='object'))
numerical = pd.DataFrame(numerical, index = X_train.index)
df_train = train_dummies_trans_df.merge(numerical, left_index = True , right_index=True)

# %%
numerical1 = (X_test.select_dtypes(exclude='object'))
numerical1 = pd.DataFrame(numerical1, index = X_test.index)
df_test = test_dummies_trans_df.merge(numerical1, left_index = True , right_index=True)

# %%
df_train.head()
# Out:
#        host_response_time_a few days or more  host_response_time_within a day  \
# 24282                                    0.0                              0.0
# 18640                                    0.0                              0.0
# 32591                                    0.0                              0.0
# 1015                                     1.0                              0.0
# 14189                                    0.0                              0.0
#
#        host_response_time_within a few hours  \
# 24282                                    0.0
# 18640                                    0.0
# 32591                                    0.0
# 1015                                     0.0
# 14189                                    0.0
#
#        host_response_time_within an hour  host_has_profile_pic_f  \
# 24282                                1.0                     0.0
# 18640                                1.0                     0.0
# 32591                                1.0                     0.0
# 1015                                 0.0                     0.0
# 14189                                1.0                     0.0
#
#        host_has_profile_pic_t  host_identity_verified_f  \
# 24282                     1.0                       0.0
# 18640                     1.0                       0.0
# 32591                     1.0                       0.0
# 1015                      1.0                       0.0
# 14189                     1.0                       0.0
#
#        host_identity_verified_t  host_is_superhost_f  host_is_superhost_t  \
# 24282                       1.0                  1.0                  0.0
# 18640                       1.0                  1.0                  0.0
# 32591                       1.0                  1.0                  0.0
# 1015                        1.0                  1.0                  0.0
# 14189                       1.0                  0.0                  1.0
#
#        ...     60     61     62     63     64     65     66     67     68  \
# 24282  ...   4.83   6.47   6.47   6.47   4.97   4.97   5.96   6.38   4.83
# 18640  ...   6.86   8.35   8.35   8.35   6.97   6.96   7.87   8.27   6.86
# 32591  ...   6.20   5.54   5.54   5.54   6.13   6.08   5.65   5.54   6.20
# 1015   ...   4.06   3.10   3.10   3.10   3.96   3.92   3.29   3.11   4.06
# 14189  ...  24.67  24.33  24.33  24.33  24.63  24.58  24.37  24.32  24.67
#
#           69
# 24282   5.84
# 18640   8.03
# 32591   6.73
# 1015    4.35
# 14189  25.45
#
# [5 rows x 108 columns]

# %%
def print_cv_scores(pipe, X, y):
    '''
    Runs cross_validate on given feature and class target arrays using given pipeline, 
    printing the scoring results for both training and cross_val.
    '''
    scoring = ['accuracy','precision', 'recall', 'f1']
    
    results = cross_validate(pipe, X, 
                                   y, 
                                   return_train_score=True, scoring=scoring, cv=5)
    
    print(results['train_accuracy'])
    print('Training Accuracy', results['train_accuracy'].mean())
    print('##############')
    print('Cross_Val Accuracy', results['train_accuracy'].mean())
    print('##############')
    print('Training Precision:', results['train_precision'].mean())
    print('##############')
    print('Training  Recall:', results['train_recall'].mean())
    print('##############')
    print('Training  F1:', results['train_f1'].mean())

# %%
fsm_pip = Pipeline([('nb', MultinomialNB())
                    ])

fsm_pip.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('nb', MultinomialNB())])

# %%
print_cv_scores(fsm_pip, df_train, y_train)
# Out:
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [0.9423103  0.62000632 0.94222262 0.94226776 0.94226776]
# Training Accuracy 0.8778149527545025
# ##############
# Cross_Val Accuracy 0.8778149527545025
# ##############
# Training Precision: 0.5263032930731908
# ##############
# Training  Recall: 0.19984350566849102
# ##############
# Training  F1: 0.04771993466614066

# %% [markdown]
# ## log

# %%
log_pipe = Pipeline([('lg', LogisticRegression(solver='liblinear',max_iter=100000000))
                    ])
log_pipe.fit(df_train,  y_train)
# Out:
# Pipeline(steps=[('lg',
#                  LogisticRegression(max_iter=100000000, solver='liblinear'))])

# %%
print_cv_scores(log_pipe, df_train, y_train)
# Out:
# [0.94167833 0.94321311 0.94208721 0.94208721 0.94208721]
# Training Accuracy 0.9422306120017769
# ##############
# Cross_Val Accuracy 0.9422306120017769
# ##############
# Training Precision: 0.41319679126130743
# ##############
# Training  Recall: 0.012196295934323687
# ##############
# Training  F1: 0.02330699193099959

# %% [markdown]
# ## Log and scaled

# %%
log_pipe_scale = Pipeline([('ss', StandardScaler() ),
                           ('lg', LogisticRegression(solver='liblinear',max_iter=100000000))
                    ])
log_pipe_scale.fit(df_train,  y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()),
#                 ('lg',
#                  LogisticRegression(max_iter=100000000, solver='liblinear'))])

# %%
print_cv_scores(log_pipe_scale, df_train, y_train)
# Out:
# [0.94434162 0.94425134 0.94384761 0.94411844 0.94425386]
# Training Accuracy 0.9441625764463941
# ##############
# Cross_Val Accuracy 0.9441625764463941
# ##############
# Training Precision: 0.6280452468112099
# ##############
# Training  Recall: 0.08098978694292416
# ##############
# Training  F1: 0.14339848352082993

# %%
grid = {'lg__class_weight': [None,'balanced'], 
         'lg__tol': [0.0001, 0.01, 0.1],
         'lg__C' : [0.0001,0.001,0.01],
         'lg__penalty': ['l1', 'l2']
        }

# %%
gridsearch = GridSearchCV(log_pipe_scale, grid, return_train_score=True, scoring='precision',verbose=2)

gridsearch.fit(df_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.6s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.4s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   2.0s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   1.7s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   2.1s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.5s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.9s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.5s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.0001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.5s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.8s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.9s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.5s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.6s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.9s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.7s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.4s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.6s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.4s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.001, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.2s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.4s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   1.8s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.7s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.5s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.4s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.001, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.4s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.4s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.0001; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.8s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   1.3s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.4s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.01; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.6s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   0.8s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.0001; total time=   1.6s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.8s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.9s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.8s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=None, lg__penalty=l2, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.0001; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.9s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.7s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.01; total time=   0.6s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l1, lg__tol=0.1; total time=   0.3s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.8s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.9s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.8s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.7s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.0001; total time=   0.7s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.01; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.5s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.4s
# [CV] END lg__C=0.01, lg__class_weight=balanced, lg__penalty=l2, lg__tol=0.1; total time=   0.5s
# GridSearchCV(estimator=Pipeline(steps=[('ss', StandardScaler()),
#                                        ('lg',
#                                         LogisticRegression(max_iter=100000000,
#                                                            solver='liblinear'))]),
#              param_grid={'lg__C': [0.0001, 0.001, 0.01],
#                          'lg__class_weight': [None, 'balanced'],
#                          'lg__penalty': ['l1', 'l2'],
#                          'lg__tol': [0.0001, 0.01, 0.1]},
#              return_train_score=True, scoring='precision', verbose=2)

# %%
print('gridsearch best parameters: {}'.format(gridsearch.best_params_))
print('gridsearch best score: {}'.format(gridsearch.best_score_))
# Out:
# gridsearch best parameters: {'lg__C': 0.0001, 'lg__class_weight': None, 'lg__penalty': 'l2', 'lg__tol': 0.0001}
# gridsearch best score: 0.6

# %%
log_pipe2 = Pipeline([('lg', LogisticRegression(C=0.0001, solver='liblinear',max_iter=100000000))
                    ])
log_pipe2.fit(df_train,  y_train)
# Out:
# Pipeline(steps=[('lg',
#                  LogisticRegression(C=0.0001, max_iter=100000000,
#                                     solver='liblinear'))])

# %%
print_cv_scores(log_pipe2, df_train, y_train)
# Out:
# [0.94212973 0.94240058 0.94235804 0.94208721 0.94204207]
# Training Accuracy 0.9422035255963882
# ##############
# Cross_Val Accuracy 0.9422035255963882
# ##############
# Training Precision: 0.4892610313662945
# ##############
# Training  Recall: 0.005159548475371384
# ##############
# Training  F1: 0.010202205489577756

# %% [markdown]
# ## Log with smote

# %%
log_smote_pipe = imbpipe([('smote', SMOTE()),
                        ('lg', LogisticRegression(C=0.0001,solver='liblinear',max_iter=100000000))
                    ])

# %%
log_smote_pipe.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTE()),
#                 ('lg',
#                  LogisticRegression(C=0.01, max_iter=100000000,
#                                     solver='liblinear'))])

# %%
print_cv_scores(log_smote_pipe, df_train, y_train)
# Out:
# [0.64523992 0.84029251 0.63785321 0.64530107 0.65360657]
# Training Accuracy 0.6844586578715675
# ##############
# Cross_Val Accuracy 0.6844586578715675
# ##############
# Training Precision: 0.16109749932014733
# ##############
# Training  Recall: 0.9668505668491008
# ##############
# Training  F1: 0.2727449651481928

# %%
log_smote_pipe_sc = imbpipe([('ss', StandardScaler()),
                        ('smote', SMOTE()),
                        ('lg', LogisticRegression(C=0.0001,solver='liblinear',max_iter=100000000))
                    ])

log_smote_pipe_sc.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()), ('smote', SMOTE()),
#                 ('lg',
#                  LogisticRegression(C=0.0001, max_iter=100000000,
#                                     solver='liblinear'))])

# %%
print_cv_scores(log_smote_pipe_sc, df_train, y_train)
# Out:
# [0.66848734 0.66902903 0.66845716 0.66764467 0.66787036]
# Training Accuracy 0.6682977116219505
# ##############
# Cross_Val Accuracy 0.6682977116219505
# ##############
# Training Precision: 0.14694254120900102
# ##############
# Training  Recall: 0.9873361757232212
# ##############
# Training  F1: 0.2558130258297735

# %%
log_smote_pipe_sc2 = imbpipe([('ss', StandardScaler()),
                        ('smote', SMOTE()),
                        ('lg', LogisticRegression(solver='liblinear',max_iter=100000000))
                    ])

log_smote_pipe_sc2.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()), ('smote', SMOTE()),
#                 ('lg',
#                  LogisticRegression(max_iter=100000000, solver='liblinear'))])

# %%
print_cv_scores(log_smote_pipe_sc2, df_train, y_train)
# Out:
# [0.81672911 0.8203855  0.81335199 0.81660197 0.81443532]
# Training Accuracy 0.8163007774181821
# ##############
# Cross_Val Accuracy 0.8163007774181821
# ##############
# Training Precision: 0.23181876231632276
# ##############
# Training  Recall: 0.9426196002736512
# ##############
# Training  F1: 0.3721144892816526

# %% [markdown]
# ## Random Forest

# %%
rf_pipe = Pipeline([('rf', RandomForestClassifier())
                    ])
rf_pipe.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('rf', RandomForestClassifier())])

# %%
print_cv_scores(rf_pipe, df_train, y_train)
# Out:
# [1.         1.         1.         0.99995486 1.        ]
# Training Accuracy 0.9999909722849146
# ##############
# Cross_Val Accuracy 0.9999909722849146
# ##############
# Training Precision: 1.0
# ##############
# Training  Recall: 0.9998436278342455
# ##############
# Training  F1: 0.9999217833398515

# %%
grid2 = {"rf__class_weight": [None, 'balanced'],
        "rf__n_estimators": [10,25 , 50], 
        "rf__max_depth" : [10, 15, 20], 
        "rf__min_samples_leaf" : [1, 2, 3]
       
       
       }

gridsearch2 = GridSearchCV(rf_pipe, grid2, return_train_score=True, scoring='precision',verbose=2)

# %%
gridsearch2.fit(df_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.4s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   2.2s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.4s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.4s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.9s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.7s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.1s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.4s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=None, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.7s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.2s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.9s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.9s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.8s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.5s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.2s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.1s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.7s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.1s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.8s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.7s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.3s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.6s
# [CV] END rf__class_weight=None, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.8s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.2s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=10, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.8s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.9s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   6.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   6.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   2.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.8s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.8s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.9s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.3s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.4s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=15, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   2.9s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=1, rf__n_estimators=50; total time=   3.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=10; total time=   0.7s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   2.9s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=2, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=10; total time=   0.6s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=25; total time=   1.5s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   3.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   3.1s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   3.0s
# [CV] END rf__class_weight=balanced, rf__max_depth=20, rf__min_samples_leaf=3, rf__n_estimators=50; total time=   2.9s
# GridSearchCV(estimator=Pipeline(steps=[('rf', RandomForestClassifier())]),
#              param_grid={'rf__class_weight': [None, 'balanced'],
#                          'rf__max_depth': [10, 15, 20],
#                          'rf__min_samples_leaf': [1, 2, 3],
#                          'rf__n_estimators': [10, 25, 50]},
#              return_train_score=True, scoring='precision', verbose=2)

# %%
print('gridsearch best parameters: {}'.format(gridsearch2.best_params_))
print('gridsearch best score: {}'.format(gridsearch2.best_score_))
# Out:
# gridsearch best parameters: {'rf__class_weight': None, 'rf__max_depth': 10, 'rf__min_samples_leaf': 1, 'rf__n_estimators': 10}
# gridsearch best score: 0.6354978354978356

# %%
#gridsearch2.best_estimator_[0].feature_importances_

# %%
feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(df_train.columns, gridsearch2.best_estimator_[0].feature_importances_):
    feats[feature] = importance #add the name/value pair

# %%
importances = pd.DataFrame.from_dict(feats, orient='index')

# %%
feats
# Out:
# {'host_response_time_a few days or more': 0.0004273777814198873,
#  'host_response_time_within a day': 0.0017472740434339002,
#  'host_response_time_within a few hours': 0.0018088835516388486,
#  'host_response_time_within an hour': 0.016076905518335093,
#  'host_has_profile_pic_f': 0.0005858360662491632,
#  'host_has_profile_pic_t': 0.0,
#  'host_identity_verified_f': 0.012842438093619993,
#  'host_identity_verified_t': 0.00015341256857409347,
#  'host_is_superhost_f': 0.0047045345806713094,
#  'host_is_superhost_t': 0.00576259666407153,
#  'neighbourhood_group_cleansed_Bronx': 0.0,
#  'neighbourhood_group_cleansed_Brooklyn': 0.0002736490372647651,
#  'neighbourhood_group_cleansed_Manhattan': 0.0007975987689209354,
#  'neighbourhood_group_cleansed_Queens': 0.00021757432913759936,
#  'neighbourhood_group_cleansed_Staten Island': 2.715593090582299e-05,
#  'room_type_Entire home/apt': 0.0067704453290715946,
#  'room_type_Hotel room': 0.0,
#  'room_type_Private room': 0.0023089459978566265,
#  'room_type_Shared room': 0.00016631128559430264,
#  'instant_bookable_f': 0.04524210509178864,
#  'instant_bookable_t': 0.059113540180650306,
#  'Condition_In': 0.0,
#  'Condition_Out': 0.0004245783736411043,
#  'host_listings_count': 0.01091274015969385,
#  'host_total_listings_count': 0.012550763812014712,
#  'accommodates': 0.016024275599333473,
#  'bathrooms_text': 0.0027057515243179937,
#  'bedrooms': 0.0019971687076020647,
#  'beds': 0.004022363740934764,
#  'price': 0.015149696116812956,
#  'minimum_nights': 0.04363147589644659,
#  'maximum_nights': 0.009476263809870262,
#  'availability_30': 0.03402120949923894,
#  'availability_60': 0.049032893489128045,
#  'availability_90': 0.06763906045056338,
#  'availability_365': 0.05167397333470528,
#  'number_of_reviews': 0.026839966946550376,
#  'review_scores_rating': 0.023245836491290348,
#  'review_scores_accuracy': 0.010304022433492597,
#  'review_scores_cleanliness': 0.017325709012909054,
#  'review_scores_checkin': 0.017830234194801595,
#  'review_scores_communication': 0.007779440328182001,
#  'review_scores_location': 0.006172788641317371,
#  'calculated_host_listings_count': 0.023792001412351,
#  'calculated_host_listings_count_entire_homes': 0.02430134841819144,
#  'calculated_host_listings_count_private_rooms': 0.009540174828246973,
#  'calculated_host_listings_count_shared_rooms': 0.0005657728695940135,
#  'years_been_host': 0.014127459792265934,
#  'number_of_verifications': 0.005171886129414698,
#  'number_of_amenities': 0.11927889327774169,
#  'distance_ts': 0.007267994501414583,
#  3: 0.00502979132481125,
#  4: 0.0030610728850219418,
#  5: 0.0049815884373180805,
#  6: 0.0025075825934731412,
#  7: 0.004222734650499618,
#  8: 0.0028253213364598123,
#  10: 0.0006050531558878969,
#  11: 0.0060195733173284156,
#  12: 0.002709234954164026,
#  14: 0.003780646944640367,
#  15: 0.002907940452306193,
#  16: 0.0027376730120878224,
#  17: 0.002422334477027293,
#  18: 0.006536202044356634,
#  19: 0.00820737540582462,
#  21: 0.002487819695632668,
#  22: 0.0007358263079855094,
#  23: 0.0036489871298394814,
#  24: 0.0024403718713781656,
#  25: 0.0025321779079100605,
#  26: 0.002757238626419624,
#  29: 0.011212648710111262,
#  30: 0.0030124660251001248,
#  33: 0.001895813741249075,
#  34: 0.004192848594335242,
#  35: 0.006629367553597635,
#  36: 0.0021905758404956446,
#  37: 0.003417536397996513,
#  39: 0.006943950536658849,
#  41: 0.0030099295936098997,
#  42: 0.0033546594245104735,
#  43: 0.002077744010007829,
#  44: 0.0016290884751024436,
#  45: 0.0028465826490525884,
#  46: 0.004682842934340473,
#  47: 0.0015575537860044908,
#  48: 0.005852584801250104,
#  49: 0.0028238617121539513,
#  50: 0.00521369985345801,
#  51: 0.003544870555668829,
#  52: 0.0048596848940196695,
#  53: 0.00323611025675399,
#  54: 0.0025590714331881863,
#  55: 0.006114064366170245,
#  56: 0.0038224834279444704,
#  58: 0.002512964812374007,
#  59: 0.002768469158524853,
#  60: 0.004025853201150601,
#  61: 0.006523330886486388,
#  62: 0.0054246507265851025,
#  63: 0.0031349050264345285,
#  64: 0.002641629176684359,
#  65: 0.0015191405551220963,
#  66: 0.001910540778689481,
#  67: 0.003983617492137681,
#  68: 0.0015055913874398134,
#  69: 0.0023803920839469634}

# %%
max(feats, key=feats.get)
# Out:
# 'number_of_amenities'

# %%
feat_importances = pd.Series(gridsearch2.best_estimator_[0].feature_importances_, index=df_train.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.title("Top 15 important features")
plt.show()

# %%
rf_pipe2 = Pipeline([('rf', RandomForestClassifier(n_estimators=10, max_depth=10, min_samples_leaf=1))
                    ])

# %%
rf_pipe2.fit(df_train,y_train)
# Out:
# Pipeline(steps=[('rf', RandomForestClassifier(max_depth=10, n_estimators=10))])

# %%
print_cv_scores(rf_pipe2, df_train, y_train)
# Out:
# [0.945425   0.94474789 0.94623996 0.94542746 0.94434414]
# Training Accuracy 0.9452368888046273
# ##############
# Cross_Val Accuracy 0.9452368888046273
# ##############
# Training Precision: 0.9341623746299778
# ##############
# Training  Recall: 0.056126246090695865
# ##############
# Training  F1: 0.1054794954285863

# %%
plot_confusion_matrix(rf_pipe2, df_train, y_train,normalize = 'pred');

# %%
rf_pipe3 = Pipeline([('rf', RandomForestClassifier(n_estimators=10, max_depth=10, min_samples_leaf=1))
                    ])
rf_pipe3.fit(df_train,y_train)
# Out:
# Pipeline(steps=[('rf', RandomForestClassifier(max_depth=10, n_estimators=10))])

# %%
print_cv_scores(rf_pipe3, df_train, y_train)
# Out:
# [0.9473209  0.94650837 0.9448858  0.94479552 0.94614968]
# Training Accuracy 0.94593205587504
# ##############
# Cross_Val Accuracy 0.94593205587504
# ##############
# Training Precision: 0.9383389074693422
# ##############
# Training  Recall: 0.06863980648944487
# ##############
# Training  F1: 0.1271607457712431

# %% [markdown]
# ## RANDOM WITH SCALED

# %%
rf_pipe_scaled = Pipeline([('ss', StandardScaler()),
                    ('rf', RandomForestClassifier(n_estimators=10, max_depth=10))
                    ])
rf_pipe_scaled.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()),
#                 ('rf', RandomForestClassifier(max_depth=10, n_estimators=10))])

# %%
print_cv_scores(rf_pipe_scaled, df_train, y_train)
# Out:
# [0.94646323 0.94614725 0.94466011 0.94623996 0.94506635]
# Training Accuracy 0.9457153797100448
# ##############
# Cross_Val Accuracy 0.9457153797100448
# ##############
# Training Precision: 0.9276941132184099
# ##############
# Training  Recall: 0.06551297400312743
# ##############
# Training  F1: 0.12187350119247502

# %% [markdown]
# ## RANDOM WITH SMOTE

# %%
rf_pipe_sm = imbpipe([('smote', SMOTE()),
                    ('rf', RandomForestClassifier(n_estimators=10, max_depth=10))
                    ])

rf_pipe_sm.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTE()),
#                 ('rf', RandomForestClassifier(max_depth=10, n_estimators=10))])

# %%
print_cv_scores(rf_pipe_sm, df_train, y_train)
# Out:
# [0.88931522 0.8922945  0.88494177 0.89238964 0.88692787]
# Training Accuracy 0.8891737980474341
# ##############
# Cross_Val Accuracy 0.8891737980474341
# ##############
# Training Precision: 0.32459226640130084
# ##############
# Training  Recall: 0.8497504153635653
# ##############
# Training  F1: 0.4696715713347799

# %%
rf_pipe_sm2 = imbpipe([('smote', SMOTE()),
                    ('rf', RandomForestClassifier(max_depth=10, min_samples_leaf=1))
                    ])

rf_pipe_sm2.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTE()),
#                 ('rf', RandomForestClassifier(max_depth=10))])

# %%
print_cv_scores(rf_pipe_sm2, df_train, y_train)
# Out:
# [0.89062429 0.89364872 0.88792092 0.89369865 0.89433059]
# Training Accuracy 0.892044635488042
# ##############
# Cross_Val Accuracy 0.892044635488042
# ##############
# Training Precision: 0.3323602251643762
# ##############
# Training  Recall: 0.8613184128225176
# ##############
# Training  F1: 0.4796018304999807

# %% [markdown]
# ## RANDOM WITH SCALE AND SMOTE

# %%
rf_pipe_sm_sc = imbpipe([('ss', StandardScaler()),
                    ('smote', SMOTE()),
                    ('rf', RandomForestClassifier(n_estimators=10, max_depth=10, min_samples_leaf=1))
                    ])

rf_pipe_sm_sc.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()), ('smote', SMOTE()),
#                 ('rf', RandomForestClassifier(max_depth=10, n_estimators=10))])

# %%
print_cv_scores(rf_pipe_sm_sc,df_train, y_train )
# Out:
# [0.8716201  0.87812034 0.87609461 0.88133069 0.8820529 ]
# Training Accuracy 0.8778437279086528
# ##############
# Cross_Val Accuracy 0.8778437279086528
# ##############
# Training Precision: 0.3092836917518566
# ##############
# Training  Recall: 0.9033787382720876
# ##############
# Training  F1: 0.46075645207792293

# %%
rf_pipe_sm_sc2 = imbpipe([('ss', StandardScaler()),
                    ('smote', SMOTE()),
                    ('rf', RandomForestClassifier())
                    ])

rf_pipe_sm_sc2.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()), ('smote', SMOTE()),
#                 ('rf', RandomForestClassifier())])

# %%
print_cv_scores(rf_pipe_sm_sc2,df_train, y_train )
# Out:
# [1. 1. 1. 1. 1.]
# Training Accuracy 1.0
# ##############
# Cross_Val Accuracy 1.0
# ##############
# Training Precision: 1.0
# ##############
# Training  Recall: 1.0
# ##############
# Training  F1: 1.0

# %%
rf_pipe_sm_sc3 = imbpipe([('ss', StandardScaler()),
                    ('smote', SMOTE()),
                    ('rf', RandomForestClassifier(n_estimators=10, max_depth=25, min_samples_leaf=1))
                    ])

rf_pipe_sm_sc3.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()), ('smote', SMOTE()),
#                 ('rf', RandomForestClassifier(max_depth=25, n_estimators=10))])

# %%
print_cv_scores(rf_pipe_sm_sc3, df_train, y_train)
# Out:
# [0.97729427 0.97404415 0.97553489 0.97837862 0.97210436]
# Training Accuracy 0.9754712588103203
# ##############
# Cross_Val Accuracy 0.9754712588103203
# ##############
# Training Precision: 0.7076162599387894
# ##############
# Training  Recall: 0.9818632720875684
# ##############
# Training  F1: 0.8223513250020952

# %% [markdown]
# ## XGBOOST

# %%
xgb_pipe = Pipeline([('xgb', XGBClassifier(objective='binary:logistic',use_label_encoder=False, eval_metric='logloss'))
                    ])

# %%
xgb_pipe.fit(df_train,y_train)
# Out:
# Pipeline(steps=[('xgb',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eval_metric='logloss',
#                                gamma=0, gpu_id=-1, importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=4, num_parallel_tree=1, random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                subsample=1, tree_method='exact',
#                                use_label_encoder=False, validate_parameters=1,
#                                verbosity=None))])

# %%
print_cv_scores(xgb_pipe, df_train, y_train)
# Out:
# [0.98203404 0.98207918 0.98212512 0.98068069 0.98031958]
# Training Accuracy 0.9814477215239925
# ##############
# Cross_Val Accuracy 0.9814477215239925
# ##############
# Training Precision: 0.9626755863661508
# ##############
# Training  Recall: 0.7060654075449568
# ##############
# Training  F1: 0.8146321512246626

# %%
grid3 = {"xgb__max_depth": [10, 15, 20],
        "xgb__min_child_weight": [10, 25, 50], 
        "xgb__colsample_bytree" : [1, 2, 3, 4]
       
       
       }

gridsearch3 = GridSearchCV(xgb_pipe, grid3, return_train_score=True, scoring='precision',verbose=2)

# %%
gridsearch3.fit(df_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=10; total time=  14.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=10; total time=  13.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=10; total time=  13.2s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=10; total time=  13.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=10; total time=  13.2s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=25; total time=  12.9s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=25; total time=  12.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=25; total time=  12.3s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=25; total time=  14.9s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=25; total time=  12.2s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=50; total time=  10.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=50; total time=  10.7s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=50; total time=  11.3s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=50; total time=  10.4s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=10, xgb__min_child_weight=50; total time=  10.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=10; total time=  18.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=10; total time=  18.6s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=10; total time=  17.8s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=10; total time=  20.3s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=10; total time=  18.4s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=25; total time=  14.9s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=25; total time=  20.5s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=25; total time=  17.2s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=25; total time=  15.1s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=25; total time=  15.4s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=50; total time=  11.1s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=50; total time=  11.1s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=50; total time=  15.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=50; total time=  11.6s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=15, xgb__min_child_weight=50; total time=  11.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=10; total time=  21.3s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=10; total time=  21.1s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=10; total time=  21.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=10; total time=  21.6s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=10; total time=  26.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=25; total time=  16.8s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=25; total time=  16.1s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=25; total time=  16.3s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=25; total time=  15.9s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=25; total time=  15.8s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=50; total time=  11.3s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=50; total time=  10.6s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=50; total time=  11.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=50; total time=  11.0s
# [CV] END xgb__colsample_bytree=1, xgb__max_depth=20, xgb__min_child_weight=50; total time=  11.1s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=10; total time=   0.1s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=25; total time=   0.1s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=50; total time=   0.0s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=10, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=15, xgb__min_child_weight=10; total time=   0.0s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=15, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=15, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=15, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=15, xgb__min_child_weight=10; total time=   0.0s
# [CV] END xgb__colsample_bytree=2, xgb__max_depth=15, xgb__min_child_weight=25; total time=   0.0s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
# ...
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=25; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=50; total time=   0.0s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 436, in inner_f
#     return f(**kwargs)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 1499, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/xgboost/core.py", line 210, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 4 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=50; total time=   0.0s
# [CV] END xgb__colsample_bytree=4, xgb__max_depth=20, xgb__min_child_weight=50; total time=   0.0s
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.45512603 0.47760325 0.48742386 0.44392104 0.4657689  0.49508436
#  0.42770092 0.45060723 0.49508436        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/raylinsoriano/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the train scores are non-finite: [0.96375305 0.90082799 0.82604653 0.99201819 0.93911723 0.83474895
#  0.99722704 0.94785937 0.83474895        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=Pipeline(steps=[('xgb',
#                                         XGBClassifier(base_score=0.5,
#                                                       booster='gbtree',
#                                                       colsample_bylevel=1,
#                                                       colsample_bynode=1,
#                                                       colsample_bytree=1,
#                                                       eval_metric='logloss',
#                                                       gamma=0, gpu_id=-1,
#                                                       importance_type='gain',
#                                                       interaction_constraints='',
#                                                       learning_rate=0.300000012,
#                                                       max_delta_step=0,
#                                                       max_depth=6,
#                                                       min_child_weight=1,
#                                                       missing=nan,
#                                                       monotone_constraints='()',
#                                                       n_estimators=100,
#                                                       n_jobs=4,
#                                                       num_parallel_tree=1,
#                                                       random_state=0,
#                                                       reg_alpha=0, reg_lambda=1,
#                                                       scale_pos_weight=1,
#                                                       subsample=1,
#                                                       tree_method='exact',
#                                                       use_label_encoder=False,
#                                                       validate_parameters=1,
#                                                       verbosity=None))]),
#              param_grid={'xgb__colsample_bytree': [1, 2, 3, 4],
#                          'xgb__max_depth': [10, 15, 20],
#                          'xgb__min_child_weight': [10, 25, 50]},
#              return_train_score=True, scoring='precision', verbose=2)

# %%
print('gridsearch best parameters: {}'.format(gridsearch3.best_params_))
print('gridsearch best score: {}'.format(gridsearch3.best_score_))
# Out:
# gridsearch best parameters: {'xgb__colsample_bytree': 1, 'xgb__max_depth': 15, 'xgb__min_child_weight': 50}
# gridsearch best score: 0.49508436367477077

# %%
xgb_pipe2 = Pipeline([('xgb', XGBClassifier(colsample_bytree= 1, max_depth= 15, min_child_weight= 50, 
                                            eval_metric='logloss', use_label_encoder=False))
                    ])


xgb_pipe2.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('xgb',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eval_metric='logloss',
#                                gamma=0, gpu_id=-1, importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=15, min_child_weight=50, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=4, num_parallel_tree=1, random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                subsample=1, tree_method='exact',
#                                use_label_encoder=False, validate_parameters=1,
#                                verbosity=None))])

# %%
print_cv_scores(xgb_pipe2, df_train, y_train)
# Out:
# [0.9600957  0.96023112 0.96136138 0.96054889 0.95996208]
# Training Accuracy 0.9604398332293765
# ##############
# Cross_Val Accuracy 0.9604398332293765
# ##############
# Training Precision: 0.8347489522354372
# ##############
# Training  Recall: 0.3927448201720094
# ##############
# Training  F1: 0.5341180231307922

# %%
plot_confusion_matrix(xgb_pipe2, df_train, y_train, normalize = 'pred');

# %%
pd.DataFrame(xgb_pipe2.predict_proba(df_train)*100, columns=xgb_pipe2.classes_)
# Out:
#                0         1
# 0      98.825829  1.174170
# 1      99.831696  0.168306
# 2      99.938042  0.061958
# 3      99.940300  0.059701
# 4      99.902725  0.097276
# ...          ...       ...
# 27687  93.885300  6.114702
# 27688  99.948494  0.051505
# 27689  95.687805  4.312195
# 27690  99.760468  0.239532
# 27691  99.140343  0.859658
#
# [27692 rows x 2 columns]

# %%
xgb_sm_pipe = imbpipe([('smote', SMOTE()),
                        ('xgb', XGBClassifier(colsample_bytree= 1, max_depth= 15, min_child_weight= 25, 
                                            eval_metric='logloss', use_label_encoder=False))
                    ])

xgb_sm_pipe.fit(df_train,y_train)
# Out:
# Pipeline(steps=[('smote', SMOTE()),
#                 ('xgb',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eval_metric='logloss',
#                                gamma=0, gpu_id=-1, importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=15, min_child_weight=25, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=4, num_parallel_tree=1, random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                subsample=1, tree_method='exact',
#                                use_label_encoder=False, validate_parameters=1,
#                                verbosity=None))])

# %%
print_cv_scores(xgb_sm_pipe,df_train,y_train)
# Out:
# [0.98185347 0.97941588 0.98212512 0.98072583 0.98063555]
# Training Accuracy 0.9809511715207551
# ##############
# Cross_Val Accuracy 0.9809511715207551
# ##############
# Training Precision: 0.8740586031070684
# ##############
# Training  Recall: 0.7829887851837373
# ##############
# Training  F1: 0.8260088013872533

# %%
xgb_sm_pipe_sc = imbpipe([('ss', StandardScaler()),
                        ('smote', SMOTE()),
                        ('xgb', XGBClassifier(colsample_bytree= 1, max_depth= 10, min_child_weight= 25, 
                                            eval_metric='logloss', use_label_encoder=False))
                    ])

xgb_sm_pipe_sc.fit(df_train,y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()), ('smote', SMOTE()),
#                 ('xgb',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eval_metric='logloss',
#                                gamma=0, gpu_id=-1, importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=10, min_child_weight=25, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=4, num_parallel_tree=1, random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                subsample=1, tree_method='exact',
#                                use_label_encoder=False, validate_parameters=1,
#                                verbosity=None))])

# %%
print_cv_scores(xgb_sm_pipe_sc,df_train,y_train)
# Out:
# [0.97616576 0.97661716 0.97562517 0.97666336 0.97643766]
# Training Accuracy 0.9763018216386999
# ##############
# Cross_Val Accuracy 0.9763018216386999
# ##############
# Training Precision: 0.8720011258856287
# ##############
# Training  Recall: 0.6910577111024239
# ##############
# Training  F1: 0.7710394271994998

# %% [markdown]
# ## Final model

# %%
rf_pipe2.score(df_test, y_test)
# Out:
# 0.9426930993391832

# %%
y_pred = rf_pipe2.predict(df_test)

# %%
precision_score(y_test, y_pred)
# Out:
# 0.8333333333333334

# %%
plot_confusion_matrix(rf_pipe2, df_test, y_test, normalize = 'pred');
